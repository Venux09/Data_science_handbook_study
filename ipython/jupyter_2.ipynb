# %%
#jupyter notebooks ipython magic commands

# %%
def Square(x):
    "Squarring the number x "
    return x**2

for N in range(1,7):
    print(f"{N}  Sqaure is {Square(N)}")
# Out:
# 1  Sqaure is 1
# 2  Sqaure is 4
# 3  Sqaure is 9
# 4  Sqaure is 16
# 5  Sqaure is 25
# 6  Sqaure is 36

# %%
Square??
# Out:
# Signature: Square(x)
# Source:
# def Square(x):
#     "Squarring the number x "
#     return x**2
# File:      c:\users\monu verma\appdata\local\temp\ipykernel_26176\1122200981.py
# Type:      function

# %%
help(Square)
# Out:
# Help on function Square in module __main__:
#
# Square(x)
#     Squarring the number x

# %% [markdown]
# ### Running the scrips using the magic commands

# %%
# %run jupyt_2.ipynb #erthis will run code of the file of the file named as jupyter_2

# %%
# %timeit L = [N*2 for N in range(100)]
# Out:
# 6.08 μs ± 194 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%timeit 
L =  []
for N in range(100):
    L.append(N*2)
L
# Out:
# 9.51 μs ± 495 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
#here we can observe that loop is taking around 3 times more thime thatn the list comprehention

# %%
# %timeit??
# Out:
# Source:
#     @skip_doctest
#     @no_var_expand
#     @line_cell_magic
#     @needs_local_scope
#     def timeit(self, line='', cell=None, local_ns=None):
#         """Time execution of a Python statement or expression
#
#         **Usage, in line mode**::
#
#           %timeit [-n<N> -r<R> [-t|-c] -q -p<P> [-o|-v <V>]] statement
#
#         **or in cell mode**::
#
#           %%timeit [-n<N> -r<R> [-t|-c] -q -p<P> [-o|-v <V>]] setup_code
#           code
#           code...
#
#         Time execution of a Python statement or expression using the timeit
#         module.  This function can be used both as a line and cell magic:
#
#         - In line mode you can time a single-line statement (though multiple
#           ones can be chained with using semicolons).
#
#         - In cell mode, the statement in the first line is used as setup code
#           (executed but not timed) and the body of the cell is timed.  The cell
# ...

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %magic -- display magic featuers and doc string a

# %%
print(In)
# Out:
# ['', '#jupyter notebooks ipython magic commands ', 'def Square(x):\n    "Squarring the number x "\n    return x**2\n\nfor N in range(1,7):\n    print(f"{N}  Sqaure is {Square(N)}")', "get_ipython().run_line_magic('pinfo2', 'Square')", 'help(Square)', '# %run jupyt_2.ipynb #erthis will run code of the file of the file named as jupyter_2', "get_ipython().run_line_magic('timeit', 'L = [N*2 for N in range(100)]')", "get_ipython().run_cell_magic('timeit', '', 'L =  []\\nfor N in range(100):\\n    L.append(N*2)\\nL\\n')", '#here we can observe that loop is taking around 3 times more thime thatn the list comprehention ', "get_ipython().run_line_magic('pinfo2', '%timeit')", "get_ipython().run_line_magic('lsmagic', '')", '# %magic -- display magic featuers and doc string a', 'print(In)']

# %%
print(Out)
# Out:
# {10: Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
print(_)#for print the last cell ouput
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
print(_)
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
print(_)
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
print(__)#printing the second to the last

# %%
print(___) # for printing the result of the 3 of the last

# %%
# !echo "Hello world"
# Out:
# "Hello world"

# %%
#using the shell function in the python or jupyter notebook directories 
message = "Hello i am monu verma i am working in python "
# !echo {message}
# Out:
# Hello i am monu verma i am working in python

# %%
# %ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is BCE4-A89B
#
#  Directory of C:\Users\Monu Verma
#
# 22-07-2026  10:43    <DIR>          .
# 18-05-2026  19:18    <DIR>          ..
# 18-05-2026  20:56    <DIR>          .anaconda
# 22-06-2026  08:50               606 .bash_history
# 15-07-2026  08:15    <DIR>          .cache
# 18-05-2026  21:17    <DIR>          .conda
# 18-05-2026  21:12    <DIR>          .continuum
# 18-07-2026  08:51    <DIR>          .copilot
# 20-06-2026  09:26    <DIR>          .cursor
# 03-07-2026  07:19    <DIR>          .dbclient
# 21-06-2026  10:34               206 .gitconfig
# 20-05-2026  19:40    <DIR>          .ipython
# 20-05-2026  19:26    <DIR>          .jupyter
# 15-06-2026  08:39    <DIR>          .keras
# 02-07-2026  08:23                26 .lesshst
# 29-07-2026  06:59    <DIR>          .lmstudio
# 22-07-2026  07:00                29 .lmstudio-home-pointer
# 21-05-2026  18:58    <DIR>          .matplotlib
# ...

# %%
# %pwd
# Out:
# 'C:\\Users\\Monu Verma'

# %%
#function that can be used as for magic functions 
#%cat, %cp, %env, %ls, %man,
# %mkdir, %more, %mv, %pwd, %rm, and %rmdir

# %%
ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is BCE4-A89B
#
#  Directory of C:\Users\Monu Verma
#
# 22-07-2026  10:43    <DIR>          .
# 18-05-2026  19:18    <DIR>          ..
# 18-05-2026  20:56    <DIR>          .anaconda
# 22-06-2026  08:50               606 .bash_history
# 15-07-2026  08:15    <DIR>          .cache
# 18-05-2026  21:17    <DIR>          .conda
# 18-05-2026  21:12    <DIR>          .continuum
# 18-07-2026  08:51    <DIR>          .copilot
# 20-06-2026  09:26    <DIR>          .cursor
# 03-07-2026  07:19    <DIR>          .dbclient
# 21-06-2026  10:34               206 .gitconfig
# 20-05-2026  19:40    <DIR>          .ipython
# 20-05-2026  19:26    <DIR>          .jupyter
# 15-06-2026  08:39    <DIR>          .keras
# 02-07-2026  08:23                26 .lesshst
# 29-07-2026  06:59    <DIR>          .lmstudio
# 22-07-2026  07:00                29 .lmstudio-home-pointer
# 21-05-2026  18:58    <DIR>          .matplotlib
# ...

# %%
pwd
# Out:
# 'C:\\Users\\Monu Verma'

# %%
cd
# Out:
# C:\Users\Monu Verma

# %%
env
# Out:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\Monu Verma\\AppData\\Roaming',
#  'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#  'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#  'COMPUTERNAME': 'LAPTOP-DGVUO1I1',
#  'COMSPEC': 'C:\\Windows\\system32\\cmd.exe',
#  'CONDA_DEFAULT_ENV': 'base',
#  'CONDA_EXE': 'C:\\Users\\Monu Verma\\Searches\\New folder\\Scripts\\conda.exe',
#  'CONDA_PREFIX': 'C:\\Users\\Monu Verma\\Searches\\New folder',
#  'CONDA_PROMPT_MODIFIER': '(base) ',
#  'CONDA_PYTHON_EXE': 'C:\\Users\\Monu Verma\\Searches\\New folder\\python.exe',
#  'CONDA_SHLVL': '1',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'EFC_12348_1592913036': '1',
#  'EFC_12348_2946480783': '1',
#  'EFC_12348_4126798990': '1',
#  'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#  'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#  'HOMEDRIVE': 'C:',
# ...

# %%
mkdir tmp

# %%
cd
# Out:
# C:\Users\Monu Verma

# %%
# Out:
#   Cell In[46], line 1
#     rm -r tmp
#           ^
# SyntaxError: invalid syntax

# %%
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is BCE4-A89B
#
#  Directory of C:\Users\Monu Verma
#
# 29-07-2026  09:06    <DIR>          .
# 18-05-2026  19:18    <DIR>          ..
# 18-05-2026  20:56    <DIR>          .anaconda
# 22-06-2026  08:50               606 .bash_history
# 15-07-2026  08:15    <DIR>          .cache
# 18-05-2026  21:17    <DIR>          .conda
# 18-05-2026  21:12    <DIR>          .continuum
# 18-07-2026  08:51    <DIR>          .copilot
# 20-06-2026  09:26    <DIR>          .cursor
# 03-07-2026  07:19    <DIR>          .dbclient
# 21-06-2026  10:34               206 .gitconfig
# 20-05-2026  19:40    <DIR>          .ipython
# 20-05-2026  19:26    <DIR>          .jupyter
# 15-06-2026  08:39    <DIR>          .keras
# 02-07-2026  08:23                26 .lesshst
# 29-07-2026  06:59    <DIR>          .lmstudio
# 22-07-2026  07:00                29 .lmstudio-home-pointer
# 21-05-2026  18:58    <DIR>          .matplotlib
# ...
