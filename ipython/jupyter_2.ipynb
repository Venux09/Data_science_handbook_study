# %%
#jupyter notebooks ipython magic commands

# %%
def Square(x):
    "Squarring the number x "
    return x**2

for N in range(1,7):
    print(f"{N}  Sqaure is {Square(N)}")
# Out:
# 1  Sqaure is 1
# 2  Sqaure is 4
# 3  Sqaure is 9
# 4  Sqaure is 16
# 5  Sqaure is 25
# 6  Sqaure is 36

# %%
Square??
# Out:
# Signature: Square(x)
# Source:
# def Square(x):
#     "Squarring the number x "
#     return x**2
# File:      c:\users\monu verma\appdata\local\temp\ipykernel_4128\1122200981.py
# Type:      function

# %%
help(Square)
# Out:
# Help on function Square in module __main__:
#
# Square(x)
#     Squarring the number x

# %% [markdown]
# ### Running the scrips using the magic commands

# %%
# %run jupyter_2.ipynb #this will run code of the file of the file named as jupyter_2
# Out:
# 1  Sqaure is 1
# 2  Sqaure is 4
# 3  Sqaure is 9
# 4  Sqaure is 16
# 5  Sqaure is 25
# 6  Sqaure is 36
# Signature: Square(x)
# Source:
# def Square(x):
#     "Squarring the number x "
#     return x**2
# File:      c:\users\monu verma\appdata\local\temp\ipykernel_4128\1122200981.py
# Type:      function

# %%
# %timeit L = [N*2 for N in range(100)]
# Out:
# 3.43 μs ± 322 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
#taking around 3 times more time tha
# %%timeit 
L =  []
for N in range(100):
    L.append(N*2)
L
# Out:
# 9.42 μs ± 253 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
#here we can observe that loop is taking around 3 times more thime thatn the list comprehention
