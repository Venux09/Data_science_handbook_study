# %% [markdown]
# ### debugging tools in jupyter

# %%
def func1(a,b):
    "Return the division of of a by b"
    return a/b

def func2(x):
    a = x 
    b = x-1 
    return  func1(a,b)

# %%
#%xmode have three mode of errors ouput Plain , verbose , Context

# %%
# %xmode Plain
# Out:
# Exception reporting mode: Plain

# %%
# %run -d
# %pdb on
func2(1)
# Out:
# Traceback (most recent call last):
#
#   File ~\Searches\New folder\Lib\site-packages\IPython\core\magics\execution.py:727 in run
#     fpath = arg_lst[0]
#
# IndexError: list index out of range
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#
#   Cell In[8], line 1
#     get_ipython().run_line_magic('run', '-d')
#
#   File ~\Searches\New folder\Lib\site-packages\IPython\core\interactiveshell.py:2504 in run_line_magic
#     result = fn(*args, **kwargs)
#
#   File ~\Searches\New folder\Lib\site-packages\IPython\core\magics\execution.py:731 in run
#     raise Exception(msg) from e
#
# Exception: you must provide at least a filename.

# %%
# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %%
func2(1)#verbose give more context about the error than any mode of %xmode
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 func2(1)#verbose give more context about the error than any mode of %xmode
#
# Cell In[5], line 8, in func2(x=1)
#       6 a = x
#       7 b = x-1
# ----> 8 return  func1(a,b)
#         a = 1
#         b = 0
# Cell In[5], line 3, in func1(a=1, b=0)
#       1 def func1(a,b):
#       2     "Return the division of of a by b"
# ----> 3     return a/b
#         a = 1
#         b = 0
# ZeroDivisionError: division by zero

# %%
# %xmode Context
# Out:
# Exception reporting mode: Context

# %%
func2(1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 func2(1)
#
# Cell In[5], line 8, in func2(x)
#       6 a = x
#       7 b = x-1
# ----> 8 return  func1(a,b)
#
# Cell In[5], line 3, in func1(a, b)
#       1 def func1(a,b):
#       2     "Return the division of of a by b"
# ----> 3     return a/b
#
# ZeroDivisionError: division by zero

# %% [raw]
# From this i understood that if we are having hardtime debugging we have to switch to verbo ose and then we have if code is complex it will help when we are understanding zero things Plain is useless in any context but can be usefull for speed programming

# %%
pdb?
# Out:
# Docstring:
# Control the automatic calling of the pdb interactive debugger.
#
# Call as '%pdb on', '%pdb 1', '%pdb off' or '%pdb 0'. If called without
# argument it works as a toggle.
#
# When an exception is triggered, IPython can optionally call the
# interactive pdb debugger after the traceback printout. %pdb toggles
# this feature on and off.
#
# The initial state of this feature is set in your configuration
# file (the option is ``InteractiveShell.pdb``).
#
# If you want to just activate the debugger AFTER an exception has fired,
# without having to type '%pdb on' and rerunning your code, you can use
# the %debug magic.
# File:      c:\users\monu verma\searches\new folder\lib\site-packages\ipython\core\magics\execution.py
