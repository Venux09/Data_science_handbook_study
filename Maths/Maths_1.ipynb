# %%
x = 4-(4*4)/10+1 #operation on the basis of peMDas 
print(x)
# Out:
# 3.4

# %%
def f(x):#function 
    return 2*x+1

x_values = [1,2,3,4]

for x in x_values:
    y = f(x)
    print(y)
# Out:
# 3
# 5
# 7
# 9

# %%
from sympy import *
x = symbols('x')
f = x+2+1
plot(f)

# %%
#curvy linear graph 
x = symbols('x')
f = x**2 +1
plot(f)

# %%
from sympy.plotting import plot3d #importing sympy 3 dimensional groph 
x,y = symbols('x,y')#2-independent values 
f = 2*x + 3*y #f is dependent value  as it is dependent on the x and y 
plot3d(f)

# %%
#summation 
summation = sum(2*i for i in range(1,10)) 
summation
# Out:
# 90

# %%
#summation of the elements in the python 
x = [1,2,3,4,5]
n = len(x)


summation = sum(10*x[i] for i  in range (0,n))
summation
# Out:
# 150

# %%
from sympy import *
#summation 
i , n = symbols('i n')
#iterating values from i which is 1 to n 
summation = Sum(2*i,(i,1,n))#have to use Sum not sum 

#setting n as 5 so it will iterate the value then i will multiply from 1 to n then will add it 
subs_5 = summation.subs(n,5) #setting n as 5 
subs_5.doit() # do it function for running the expression
# Out:
# 30

# %%
x = symbols('x')
expression = x**3/x**6
expression
# Out:
# x**(-3)
