# %%
x = 4-(4*4)/10+1
print(x)
# Out:
# 3.4

# %%
def f(x):
    return 2*x+1

x_values = [1,2,3,4]

for x in x_values:
    y = f(x)
    print(y)
# Out:
# 3
# 5
# 7
# 9

# %%
from sympy import *
x = symbols('x')
f = x+2+1
plot(f)
