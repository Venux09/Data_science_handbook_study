# %%
#day 3 of the maths

# %%
from sympy import *

# %%
x = symbols('x')
expression = x**3/x**3 #x raise to the power 0 after dividing the equation 
expression
# Out:
# 1

# %%
#using the log function of the mathmatics 
from math import log 

a = log(5,3) # log of the number the 5 to the base to the power 3 this is the what it means
a
# Out:
# 1.4649735207179269
