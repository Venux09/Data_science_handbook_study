# %% [markdown]
# ### conditional probability and bayes's Theorm

# %%
#today i have to study the bayes's Theorm

# %%
# #Let’s say a study makes a claim that 85% of cancer patients drank coffee. How do you
# react to this claim? Does this alarm you and make you want to abandon your favorite
# morning drink? Let’s first define this as a conditional probability
# P(Coffee given Cancer) or P(Coffee|Cancer). This represents a probability of
# people who drink coffee given they have cancer.

# %%
p_cancer = 0.005
p_coffee = 0.65
p_coffee_given_cancer = 0.85 
(cancer_and_coffe_drinker) = p_coffee_given_cancer*p_cancer/p_coffee

# %%
cancer_and_coffe_drinker
# Out:
# 0.006538461538461539

# %%
#so here we get to know that being a coffee and having a cancer is different than having a cancer and being a coffee drinker
