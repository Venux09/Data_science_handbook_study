# %% [markdown]
# # Probability exercize

# %% [raw]
# Q1. There is a 30% chance of rain today, and a 40% chance your umbrella order will
# arrive on time. You are eager to walk in the rain today and cannot do so without
# either!
# What is the probability it will rain AND your umbrella will arrive?

# %%
#the probability of it will rain and my umbrella will arrive 
probability_rain = 0.3 
probbility_umbrella_will_arrive = 0.4 
probability_of_umbrella_will_arrive_with_rain_comming = probability_rain*probbility_umbrella_will_arrive


#answer 
probability_of_umbrella_will_arrive_with_rain_comming
# Out:
# 0.12

# %% [raw]
# Q2. There is a 30% chance of rain today, and a 40% chance your umbrella order will
# arrive on time.
# You will be able to run errands only if it does not rain or your umbrella arrives.
# What is the probability it will not rain OR your umbrella arrives?

# %%
#probability of not rain 
not_rain = 1-0.3
p_umbrella_arrive = 0.4 
p_umbrella_arrive_or_donot_rain = not_rain+p_umbrella_arrive-(not_rain*p_umbrella_arrive)

# %%
f"so the probability of either umbrellla will arive or it will not rain is {p_umbrella_arrive_or_donot_rain}"
# Out:
# 'so the probability of either umbrellla will arive or it will not rain is 0.8200000000000001'

# %% [raw]
# 3. There is a 30% chance of rain today, and a 40% chance your umbrella order will
# arrive on time.
# However, you found out if it rains there is only a 20% chance your umbrella will
# arrive on time.
# What is the probability it will rain AND your umbrella will arrive on time?

# %%
#answer 
p_rain = 0.3 #if we are calculating that it will rain and the umbrella have to arrive 
p_umbrella_will_arive = 0.2 #according to the question 
p_it_will_rain_and_umbrella_will_arrive = p_rain*p_umbrella_will_arive
f"So the probability of that it will rain and umbrella will also arrive is {p_it_will_rain_and_umbrella_will_arrive}"
# Out:
# 'So the probability of that it will rain and umbrella will also arrive is 0.06'

# %% [raw]
# 4. You have 137 passengers booked on a flight from Las Vegas to Dallas. However,
# it is Las Vegas on a Sunday morning and you estimate each passenger is 40%
# likely to not show up.
# You are trying to figure out how many seats to overbook so the plane does not fly
# empty.
# How likely is it at least 50 passengers will not show up?

# %%
#answer
from scipy.stats import binom 
p_passengers_will_not_show_up = 0.40 
passengers = 137 

p = 0
for x in range(50,138):
    #probability of that 50 passenger will not show up 
    p += binom.pmf(x,passengers,p_passengers_will_not_show_up)

p
# Out:
# np.float64(0.8220955881474251)

# %% [raw]
# 5. You flipped a coin 19 times and got heads 15 times and tails 4 times.
# Do you think this coin has any good probability of being fair? Why or why not?

# %%
head = 8 
tail = 2 
from scipy.stats import beta 
fair_prob_chances = 1 - beta.cdf(0.5,head,tail)

# %%
fair_prob_chances
# Out:
# np.float64(0.98046875)

# %%
#there are 98 percent unlikely chances that probability will be fair
