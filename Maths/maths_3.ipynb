# %%
#studying maths day - 4

# %%
#method of the calculating the interest rate and other thing which grows uniformaly 
from math import exp
p = 172478032
n=31536000
r=0.32329423
t=1.2324
post_2_years = p*exp(r*t)
post_2_years #money including the interst rate after the post 2 years \
# Out:
# 256902770.05797556

# %%
#e is not used for studying the populations as their growth is dependent

# %%
"Natural logarithm"
from math import log 

#e raise to the what power give us 10 
x = log(10)
y = log(7943)
y
# Out:
# 8.980046316633132

# %%
# %xmode Verbose
from math import log 
def x(number):
    "Return the Log of the given value"
    y = number
    return log(y)
x(25)
# Out:
# Exception reporting mode: Verbose
# 3.2188758248682006

# %%
# e chases the infinity growth in praticular time it is like maximum growth it can approach as it chasese the constant

# %%
#Limits
