# %% [markdown]
# # basic maths and calculus exercize

# %%
'a is a rational or irrational' 
a= 62.6738

# %%
a
# Out:
# 62.6738

# %%
'since a can be written in a/b form it is a rational number'
# Out:
# 'since a can be written in a/b form it is a rational number'

# %%
'Q.2'
# Out:
# 'Q.2'

# %%
#solution 
a = 10**-7*10**10

# %%
a
# Out:
# 1000.0

# %%
#Q3 
c = 9**2*1/2

# %%
c
# Out:
# 40.5

# %%
d = 5**3

# %%
d
# Out:
# 125

# %%
from sympy import *
c = 9**2*1/2

# %%
#question -- 5 
import sympy as sp

# %%
from math import exp
p = 1000#starting amount 
r = 5#interest rate per year 
t = 3#no of the years 
n = 12#no of the moonths in the year 
f = p*(1+(r/n))**n*t

# %%
f
# Out:
# 196034.88339245538

# %%
#if the amount in increased continously then 
f_ = p*exp(3*5)

# %%
f_
# Out:
# 3269017372.4721107

# %%
from sympy import *
x = symbols('x')
f = x**2+1
f.subs(x,3)
# Out:
# 10

# %%
from sympy import *
x,i,n = symbols('x i n')
