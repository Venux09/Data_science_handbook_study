# %%
#chapter - 4 Linear algebra 
#vector is arrow in space so ofcourse it would have direction and also would have some value
#in its intial form vector position of the tail in the cartisian plane is 0,0

# %%
#vector 
v = [2,3]

# %%
v
# Out:
# [2, 3]

# %%
#making an vecto array usin thenumpy
import numpy as np  
vector = np.array([2,3])

# %%
vector
# Out:
# array([2, 3])

# %%
#vector do looks like numbers stored but we have to remember that its aspect of direction and other thing so that
#vector are not only number but have different roles in different aspects of the work

# %% [raw]
# WHY ARE VECTORS USEFUL?
# A struggle many people have with vectors (and linear algebra in
# general) is understanding why they are useful. They are a highly
# abstract concept but they have many tangible applications. Computer
# graphics are easier to work with when you have a grasp of vectors and
# linear transformations (the fantastic Manim visualization library defines
# animations and transformations with vectors). When doing statistics and
# machine learning work, data is often imported and turned into
# numerical vectors so we can work with it. Solvers like the one in Excel
# or Python PuLP use linear programming, which uses vectors to
# maximize a solution while meeting those constraints. Even video games
# and flight simulators use vectors and linear algebra to model not just
# graphics but also physics. I think what makes vectors so hard to grasp is
# not that their application is unobvious, but rather these applications are
# so diverse it is hard to see the generalization.

# %%
#a three dimensional vector means three direction 
vector_3d = np.array([1,2,3])

# %%
vector_3d
# Out:
# array([1, 2, 3])

# %%
vector_5d = np.array([1,2,3,4,5])#it does look like simple plain array but when we visual we will see how 5 direction will make it work

# %%
#addition of  two vectors  
v = np.array([1,2,3])
w = np.array([-1,-2,-3])
v+w
# Out:
# array([0, 0, 0])

# %%
#adding two vector is easy but it is different when we see it in cartesian plane

# %%
#adding  vector is commutative means it does not matter in which  order i have to perform the function

# %%
#scaling of the vector

# %%
#multplying or dividing the vector for scalling the vector 
v*2
# Out:
# array([2, 4, 6])

# %%
v*1/2
# Out:
# array([0.5, 1. , 1.5])

# %%
v*10000
# Out:
# array([10000, 20000, 30000])

# %%
v/10000
# Out:
# array([0.0001, 0.0002, 0.0003])

# %%
#manipulatinng the vector basically means that we are manipulating the data in simple terms

# %%
#span and linear Dependence
#the whole space of the possible vectors are called span 
#when we have to vectors in the different direction we call it linearly  independent and it can have unlimited possible vectors

# %%
#the possible number of vectors become limited when they co existing on the same line it limits the possible number of vectors and they can't have many more than this

# %%
#but why do we care if there are limited or not limited i am thinkinng this now lets me see what comes next story is going good

# %%
#Linear transformation

# %%
#according to the matric - [2,3] 2 is in the position of the i hat and j is in the position of the j hat

# %%
#they are individual as [2,0] and [0,3] if we see that on the graph

# %%
#if we increase or decrease we have  to remember that other things like sampling or span or scalling is going to be different as weel

# %%
#it addition vector will also increase since the increase in the its vector

# %%
#we can't have curve or other things  in the linear algebra because it is called linear algebra

# %%
#that's the simple ideas we have got till now of vectors or algebra in the perspective of the data or scalling or whatever we call it

# %%
#matrix multiplication in  the pandas 
from numpy import array
basis = array([[1,2],[2,3]])

# %%
basis
# Out:
# array([[1, 2],
#        [2, 3]])

# %%
prod = array([1,2])

# %%
#mul
