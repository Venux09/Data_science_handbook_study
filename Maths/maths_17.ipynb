# %% [markdown]
# # Revision

# %%
#solving expressionn in the python 
a = 10 
b = 13
c = -5 
operation = (a+b)*(a-b)

# %%
operation
# Out:
# -69

# %%
operation2 = (a+b+c)/(a-b-c)

# %%
operation2
# Out:
# 9.0

# %%
#solving a function in the python in form of single varible mean straight graph y = 2x+1 
def f(x):
    return 2*x + 1 

x_values = [1,2,3,4]
for x in x_values:
    print (f(x))
# Out:
# 3
# 5
# 7
# 9

# %%
#plotting this funcition 
from sympy import *
x = symbols('x')
f = x*2+1 
plot (f)

# %%
#now plotting the square diagram and it will give the curve since the values can never be negatice
f2 = x**2+1 #f2 can never be negative 
plot(f2)

# %%
#function is always solved using onne variable values as we have studied in the differentiation 
#plotting a 2 independed varaibale graph 
from sympy.plotting import plot3d
y = symbols('y')
f3 = 2*y+2*x+1
plot3d(f3)

# %%
#summation basically summing the sum by putting the values in the varible till the range
summa = sum(2*x for x in range(1,6))

# %%
summa
# Out:
# 30

# %%
#summation of the elements 
x = [1,2,3,4]
n = len(x)
summation = sum(10*x[i] for i in range(0,n)) #here we setted the same thing but we have now variable setteded now it will do the addtion on the basis of desire x values

# %%
summation
# Out:
# 100

# %%
#exponents
from sympy import *
x = symbols('x')#setting x as symbols 
exp = x**8/x**2

# %%
exp
# Out:
# x**6

# %%
exp2 = x**3/x**3

# %%
exp2
# Out:
# 1

# %%
#logarithm in  the python 
from math  import log  
x = log(8,2)#it is like log8/log2

# %%
x
# Out:
# 3.0

# %%
log2 = log(100,10)

# %%
log2
# Out:
# 2.0

# %%
#eular's number which is a speacial number 
#value = 2.718
#so my understanding is basically that eular number is forevery apporaching values to the exponential level.

# %%
#eular number 
from math import exp
value = 100 
interest = 0.20#montly interest 
years = 2 
exp = value*exp(interest*years)
exp
# Out:
# 149.18246976412703

# %%
#limits 
x = symbols('x')
f = 1/x
def limits(f,x,value):
    limits = limit(f,x,value)
    return limits

# %%
limits(f,x,oo)
# Out:
# 0

# %%
f2 = 1/x**2 
limits(f2,x,312)
# Out:
# 1/97344

# %%
#finding the differentiation using sympy 
from sympy import *
x = symbols('x')
f = x**2 
diff_f = diff(f)

# %%
diff_f
# Out:
# 2*x

# %%
#there can no be 2 varible in  the equation so we have to take one constant or put 0 on it

# %%
#partial derivatives basically we have take one variable to solve the equation as can't solve with 2 variable and one derivative limit

# %%
from sympy import *
x,y,z = symbols('x y z')
#function  
f = x**2+y**3+x**9
f
# Out:
# x**9 + x**2 + y**3

# %%
diff(f,x)
# Out:
# 9*x**8 + 2*x

# %%
diff(f,y)
# Out:
# 3*y**2

# %%
from sympy.plotting import plot3d

# %%
plot3d(f)
