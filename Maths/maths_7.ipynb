# %%
from sympy import *

# %%
x = symbols('x') #making the x a symbol

# %%
f = x**2+1

# %%
plot(f)

# %%
#we have to find the area under the curve 

def approximate_integral(a,b,n,f):#n = no of rectangles divided to find the area under the curve
    delta_x = (b-a)/n
    total_sum = 0 


    for i in range(1,n+1):
        midpoint = 0.5 *(2*a+delta_x*(2*i-1))
        total_sum += f(midpoint)
    return total_sum*delta_x


def my_func(x):
    return x**2+1
    
# %timeit area = approximate_integral(a=0,b=1,n=1,f=my_func)
area
# Out:
# 1.55 μs ± 155 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 1000003000/3

# %%
from sympy import *

x = symbols('x')
#writing the function 
f = x**2+1  
area = integrate(f,(x,0,1))
area
# Out:
# 4/3

# %%
from sympy import  *


x= symbols('x')

#function  
f = x**5+1

area = integrate(f,(x,0,1))

area
# Out:
# 7/6

# %%
from sympy import * 

x , y = symbols('x y')


#function 
f = x**2  + y**2 

#intergration 
area = integrate(f,(x,0,1))
area
# Out:
# y**2 + 1/3
