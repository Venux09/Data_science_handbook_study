# %%
"Day - 5 of Learning maths"
# Out:
# 'Day - 5 of Learning maths'

# %%
from sympy import *

# %%
#symbol 
x = symbols('x')
#function 
f = x**2
#derivative of the function 
deriv = diff(f)
print(deriv)
# Out:
# 2*x

# %%
y = symbols('y')
f = 742374237459*y**3432974932847 #doing the complex calucation for the finding the dervivatives
deriv = diff(f)
deriv
# Out:
# 2548552147988153356915773*y**3432974932846

# %%
#using the python for the calculating the derivatives 
def dx_f(x):
    return 2*x 

slope_at_2 = dx_f(2)#derivative of the x**2 for x = 2 
print(slope_at_2)
# Out:
# 4

# %%
#calculating the 2 dimensional derivatives using the sympy '
from sympy import *
x,y = symbols('x, y')
f = 2*x**3+2*y**3
derivatives = diff(f,x)
derivatives_y =  diff(f,y)
print(diff(diff(dervatives_y)))#differentiate of the differentiate of the differentiate of the given x
# Out:
# 12

# %%
#shit typing random shit problem 
#calculating the 2 dimensional derivatives using the sympy '
from sympy import *
from sympy.plotting import plot3d
x,y = symbols('x y')
f = 8*x**4+3*y**37
derivative_x = diff(f,x)
derivative_y =  diff(f,y)
print(diff(diff(derivative_y)))#differentiate of the differentiate of the differentiate of the given x
plot3d(f)
"plotting the 3 dimensional exponential graph of this function"
# Out:
# 139860*y**34
# 'plotting the 3 dimensional exponential graph of this function'

# %%
#plotting the 3d plot 
from sympy import *
from sympy.plotting import plot3d 

#symbols 
x,y = symbols('x y')

#function 
f = x**3+y**3

derivative_x = diff(f,x)
derivative_x 
plot3d(f)
