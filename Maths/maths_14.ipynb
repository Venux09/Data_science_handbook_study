# %% [markdown]
# ### Normal distribution in the Data science

# %% [raw]
# normal distribution is like gaussian distribution which is like bell shaped and it has most of the mass in the mean which mean middle of the data

# %% [raw]
# properties of normal distribution
# 1.it is symmetrical means it has equal data on the both sides of the distributed data.
# 2.it has most mass at the mean
# 3.the tails are least likely to occur events
# 4.it resemles a lot about the daily normal activities

# %%
def variance(values):
    mean = sum(values)/len(values)#mean formula in the python 

    _variance = (sum((v-mean)**2 for v in values)/len(values))#variance formula in the python 

    return _variance 
from math import sqrt 
def std_deviation(values):
    return sqrt(variance(values))

# %%
def mean(samples):
    mean = sum(samples)/len(samples)
    return mean

# %%
#probability density functon. 
#it basically means it show the normal distribution fuction and show the density of the probability at any other points 
def normal_pdf(x:float ,variance:float, mean:float ):
    "IT is funcition based on the formula of the probability density in the stats"
    pdf = (1 / np.sqrt(2 * np.pi * variance)) * \
      np.exp(-(x - mean)**2 / (2 * variance))
    return pdf

# %%
normal_pdf??
# Out:
# Signature: normal_pdf(x: float, variance: float, mean: float)
# Source:
# def normal_pdf(x:float ,variance:float, mean:float ):
#     "IT is funcition based on the formula of the probability density in the stats"
#     pdf = (1 / np.sqrt(2 * np.pi * variance)) * \
#       np.exp(-(x - mean)**2 / (2 * variance))
#     return pdf
# File:      c:\users\monu verma\appdata\local\temp\ipykernel_29640\1942581983.py
# Type:      function

# %%
#cumulative distribution function 
from scipy.stats import norm 

mean = 64.37
std_dev = 2.99

x = norm.cdf(64.57,mean,std_dev)
x
# Out:
# np.float64(0.5266652165332735)

# %%
#findinng the area of the dog who weights in between 62 kg and 66 kg f
from scipy.stats import norm 

mean = 64.43
std_dev = 2.99

y = norm.cdf(66,mean,std_dev) - norm.cdf(62,mean,std_dev)

# %%
y
# Out:
# np.float64(0.4920450147062894)

# %%
#the s curve that we see in the cdf is a sigmoid curve

# %%
#so here we can see that most of the dogs weights in between 66 and 62 which is around 50 percent of the data

# %%
#this is how normal distributionn data is where most of the data is in the mean

# %%
#inverse of the cdf

# %%
#finding in what weight does the 95 percent golden reteriver species of dog falls in

# %%
from scipy.stats import norm 

x = norm.ppf(.95,loc = 64.73 , scale  = 2.99)
x
# Out:
# np.float64(69.6481123445849)

# %%
import random 
from scipy.stats import norm

for i in range(10000):
    random_p = random.uniform(0,1)
    random_weight  = norm.ppf(random_p , loc = 64.47 , scale = 2.99) 
    
    print(random_weight)
# Out:
# 61.06330497079639
# 64.55439419726207
# 62.764367226169064
# 67.32128498920173
# 62.384319039660205
# 65.48824962347037
# 62.234582154554985
# 69.16306288730853
# 62.16536898699635
# 67.67955712555981
# 60.39032870906574
# 68.1930391895612
# 66.45954633832426
# 63.62649409188769
# 66.45364103788597
# 69.1131491965118
# 61.028103625612964
# 62.798374779310194
# 63.85633302297787
# 67.18883490981948
# 68.74837719760687
# 69.04803055224198
# 65.76929630861386
# 61.49991683712927
# 67.48181341398787
# 69.52513891747336
# 64.22932975007569
# 66.21735734596726
# 64.75411146270082
# 65.20218367184796
# 64.39643358203357
# 64.30441269975496
# 62.504252326524075
# 66.11841445736883
# 66.07108905495522
# 64.34302189773307
# 66.74198426429302
# 67.75019994347686
# 68.21252356273395
# 71.03877299153535
# 63.20878839050581
# 68.09787165459369
# 66.40006845912063
# 64.9392009968543
# 68.13779331332242
# 67.84629923692569
# 62.35508407741335
# 64.70251822191322
# 68.27319922778823
# ...
