# %%
#odds in probability means chances of ocurrring an event/chances of not ocurrning of an event

# %%
'for example getting a head by flipping the coin is 0.5 then its odd will be 0.5/0.5 = which is 1 either it will happen or not'
# Out:
# 'for example getting a head by flipping the coin is 0.5 then its odd will be 0.5/0.5 = which is 1 either it will happen or not'

# %%
'--- joing probablity'
#find the probability that
#both events will occur together. This is known as a joint probability.
# Out:
# '--- joing probablity'

# %%
Question = "Q - probability of  that a 1 coin will get head and at same time a number 2 will be rolled on the dice"

# %%
answer = f'probability of occurring the condition at the same time is {1/2*1/6}'

# %%
answer
# Out:
# 'probability of occurring the condition at the same time is 0.08333333333333333'

# %%
'''we can notice that after applying the formula of getting a 1 and head at same time  there were 12 combination and only one which could satify what we want that's why the probability 
 
 was 1/12 which is 0.833333'''
# Out:
# "we can notice that after applying the formula of getting a 1 and head at same time  there were 12 combination and only one which could satify what we want that's why the probability \n\n was 1/12 which is 0.833333"

# %% [markdown]
# ###  mutually exclusive events

# %% [raw]
# mutually exclusive events, which are events that cannot occur
# simultaneously. For example, if I roll one die I cannot simultaneously get a 4 and a 6. I
# can only get one outcome. Getting the union probability for these cases is easy. I
# simply add them together. If I want to find the probability of getting a 4 or 6 on a die
# roll, it is going to be 2/6 = 1/3:

# %%
#calculating the mutual exclusive events 
"example we want either 4 by rolling one dice and want tails flipping one coin"
#solution 
probability_a = 1/2 
probability_b = 1/6 
mutual_a_or_b =probability_a+probability_b-(probability_a*probability_b)

# %%
print(mutual_a_or_b)
# Out:
# 0.5833333333333333

# %%
'here probability is wrong becuase the answer should be 7/12'
# Out:
# 'here probability is wrong becuase the answer should be 7/12'

# %%
#to get the right answer we have to things about it

# %%
''' points 
1.we are also counting the values which are double outcomes..
2.we have add the probability of both and then have to subtract the probability of when they occur together '''
# Out:
# ' points \n1.we are also counting the values which are double outcomes..\n2.we have add the probability of both and then have to subtract the probability of when they occur together '

# %%
#probability of the getting a 6 and getting a only tails in flipping 2 coins 
#cases - hh , tt, th, ht 
#getting only tails is 1/4
#solution

# %%
onlyt_tails = 1/4 
only_6 = 1/6
both_occuring_together = 1/4*1/6
either_1_or_2 = only_6+onlyt_tails-(both_occuring_together)

# %%
either_1_or_2#answer fo the non
# Out:
# 0.37499999999999994
