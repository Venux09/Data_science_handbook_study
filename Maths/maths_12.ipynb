# %%
#calculating the beta distribution

# %%
from scipy.stats import beta
a = 30
b = 6
p = beta.cdf(0.90,a,b)
p
# Out:
# np.float64(0.868364225158163)

# %%
#the  probability if the probability is 90 and more 
p = (1-beta.cdf(0.90,a,b))

# %%
p
# Out:
# np.float64(0.13163577484183697)

# %%
p
# Out:
# np.float64(0.13163577484183697)

# %%
p
# Out:
# np.float64(0.13163577484183697)

# %%
p
# Out:
# np.float64(0.13163577484183697)

# %%
#so here we get to know there are 22.5 percent chances that out probability will be more than 90 or more

# %% [raw]
# To get the proabibilty around 80 to 90 we have to calculate the probability and subtracting them in the range of the 80 and 90

# %%
prob_80_and_90
# Out:
# np.float64(0.3752343330000001)

# %%
#so the there are 0.37 percent of the chances that the probability will be between 80 to 90

# %%
from scipy.stats import beta 
a = 10 
b = 2 
prob_80_and_90  = beta.cdf(0.90,a,b) - beta.cdf(0.80,a,b)

# %%
#probability between 20 and 30 

prob_30_and_20  = beta.cdf(0.30,a,b) - beta.cdf(0.20,a,b)
prob_30_and_20
# Out:
# np.float64(4.631759999999998e-05)

# %% [markdown]
# ### Binomial distribution from the scracth

# %% [raw]
# comb(n,k)
#      ↓
# How many arrangements?
#
# p**k
#      ↓
# Probability of all successes
#
# (1-p)**(n-k)
#      ↓
# Probability of all failures

# %%
#building a binomial distribution 
def factorial(n:int):#so here we are making a factorial function 
    f = 1
    for i in range(n):
        f *= i+1
        return f 


#function for finding the pnc of the given number 
def binomial_coefficient(n:int,k:int):
    return factorial(n)/(factorial(k)*factorial(n-k))


#finding the binomial distribution usinng trials

def binomial_distribution(n:int,k:int,p:float):
    #we can use varibale:[] for making a value in certain binary 
    return binomial_coefficient(n,k)*(p**k)*(1-p)**(n-k)#it is the binomial distribution formula just mean that distribution * probabiliy of all success and  probabilty of the all failure

# %%
# %xmode Verbose
#finding the binomial distribution using the formula's 
n = 10 
p = 0.9 
for k in range(n+1):
    binom = binomial_distribution(k,n,p)
    print("{0}-{1}".format(k,binom))
# Out:
# Exception reporting mode: Verbose
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 6
#       4 p = 0.9
#       5 for k in range(n+1):
# ----> 6     binom = binomial_distribution(k,n,p)
#         n = 10
#         p = 0.9
#         k = 0      7     print("{0}-{1}".format(k,binom))
#
# Cell In[60], line 18, in binomial_distribution(n=0, k=10, p=0.9)
#      16 def binomial_distribution(n:int,k:int,p:float):
#      17     #we can use varibale:[] for making a value in certain binary
# ---> 18     return binomial_coefficient(n,k)*(p**k)*(1-p)**(n-k)
#         (1-p)**(n-k) = 10000000000.000023
#         p**k = 0.3486784401000001
#         1-p = 0.09999999999999998
#         n-k = -10
#         n = 0
#         k = 10
#         p = 0.9
# Cell In[60], line 11, in binomial_coefficient(n=0, k=10)
#      10 def binomial_coefficient(n:int,k:int):
# ...
