# %%
#calculating the beta distribution

# %%
from scipy.stats import beta
a = 8 
b = 2 
p = beta.cdf(0.90,a,b)
p
# Out:
# np.float64(0.7748409780000002)

# %%
#the  probability if the probability is 90 and more 
p = (1-beta.cdf(0.90,a,b))

# %%
p
# Out:
# np.float64(0.22515902199999982)

# %%
p
# Out:
# np.float64(0.22515902199999982)

# %%
p
# Out:
# np.float64(0.22515902199999982)

# %%
int(p)
