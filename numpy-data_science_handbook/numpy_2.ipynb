# %%
"Numpy attributes"
# Out:
# 'Numpy attributes'

# %%
import numpy as np 
np.random.seed()
#one dimensional array 
x1 = np.random.randint(10,size=6,dtype='int64')
#two dimensional array 
x2 = np.random.randint(293,size=(3,3))
#three dimensional array 
x3 = np.random.randint(12,size=(10,3,4))#contain multiple 2 dimensional array

# %%
#ndim is function for getting to the know the no of dimension 
x1.ndim
# Out:
# 1

# %%
x2.ndim
# Out:
# 2

# %%
x3.ndim
# Out:
# 3

# %%
x3 = np.random.randint(193,size=(100,34,3))

# %%
x3.ndim
# Out:
# 3

# %%
x3
# Out:
# array([[[135,  41, 139],
#         [130, 131,  43],
#         [ 51,  49,  41],
#         ...,
#         [143, 159, 168],
#         [ 12, 184, 122],
#         [149,  54,  16]],
#
#        [[ 26,  61, 150],
#         [ 63,   6, 116],
#         [ 32,  35,  31],
#         ...,
#         [152, 121, 177],
#         [179,  74, 191],
#         [ 83, 155,  15]],
#
#        [[105, 159,   6],
#         [189,  38,  91],
#         [ 66,   5,  18],
#         ...,
#         [128,  71,  51],
#         [ 93, 183,  10],
#         [153, 100, 112]],
#
#        ...,
#
#        [[  5, 168, 147],
#         [ 57, 173,  71],
#         [ 61, 184,  74],
#         ...,
#         [ 23, 161,  28],
#         [166,  73,  37],
#         [ 27, 167, 167]],
#
#        [[183,  29, 168],
#         [161,  68, 172],
#         [ 61, 184,  65],
#         ...,
#         [170, 158,  20],
#         [ 91, 143, 163],
#         [ 38,  73,  22]],
#
#        [[177,   0, 124],
#         [ 91, 180, 182],
#         [ 98, 174, 161],
# ...

# %%
x3.dtype
# Out:
# dtype('int32')

# %%
x2.dtype
# Out:
# dtype('int32')

# %%
x1.dtype#changed the data type from the  32 to 64
# Out:
# dtype('int64')

# %% [markdown]
# ### Checking the memory consumption of different arrays

# %%
f"Item memo {x1.itemsize} bytes"
# Out:
# 'Item memo 8 bytes'

# %%
x2.nbytes
# Out:
# 36

# %%
x1.nbytes
# Out:
# 48

# %%
"There is different nbyter for old the array"
# Out:
# 'There is different nbyter for old the array'

# %%
x3.nbytes# most here "
# Out:
# 40800

# %%
print(x1)
# Out:
# [0 0 0 0 0 5]

# %%
print(x1)
# Out:
# [0 0 0 0 0 5]

# %%
array = x1

# %%
array[0]
# Out:
# np.int64(0)

# %%
array[-1]
# Out:
# np.int64(5)

# %%
array[-1:0]
# Out:
# array([], dtype=int64)

# %%
array[:]
# Out:
# array([0, 0, 0, 0, 0, 5])

# %%
array[-1::1]
# Out:
# array([5])

# %%
array[-1:1]
# Out:
# array([], dtype=int64)

# %%
array[-1::-1]
# Out:
# array([5, 0, 0, 0, 0, 0])

# %%
array[-4]
# Out:
# np.int64(0)

# %%
array[-4] = 1

# %%
array
# Out:
# array([0, 0, 1, 0, 0, 5])

# %%
array[2] = 84007230

# %%
array
# Out:
# array([       0,        0, 84007230,        0,        0,        5])

# %%
x2
# Out:
# array([[179, 273,  57],
#        [  2, 106, 255],
#        [248, 205, 127]], dtype=int32)

# %%
x2[0,0:]
# Out:
# array([179, 273,  57], dtype=int32)

# %%
x2[1,2]
# Out:
# np.int32(255)

# %%
x1[0] = 2.3434343#this float here will reduce to the int even though we have given it the float value it adjust according the the datatypes

# %%
x1
# Out:
# array([       2,        0, 84007230,        0,        0,        5])
