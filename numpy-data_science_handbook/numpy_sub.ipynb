# %%
from PIL import  Image
import numpy as np

# %%
image = Image.open('image.png')

# %%
np.asarray(image)
# Out:
# array([[[ 54,  54,  54, 255],
#         [ 54,  54,  54, 255],
#         [ 54,  54,  55, 255],
#         ...,
#         [ 44,  45,  45, 255],
#         [ 44,  45,  45, 255],
#         [ 44,  45,  45, 255]],
#
#        [[ 55,  55,  55, 255],
#         [ 55,  55,  55, 255],
#         [ 55,  55,  55, 255],
#         ...,
#         [ 44,  45,  45, 255],
#         [ 44,  45,  45, 255],
#         [ 44,  45,  45, 255]],
#
#        [[ 55,  55,  55, 255],
#         [ 55,  55,  55, 255],
#         [ 55,  55,  55, 255],
#         ...,
#         [ 45,  45,  46, 255],
#         [ 45,  45,  46, 255],
#         [ 45,  45,  46, 255]],
#
#        ...,
#
#        [[ 88,  90,  90, 255],
#         [154, 157, 156, 255],
#         [161, 164, 163, 255],
#         ...,
#         [235, 235, 235, 255],
#         [235, 235, 235, 255],
#         [236, 236, 236, 255]],
#
#        [[ 83,  86,  85, 255],
#         [155, 158, 157, 255],
#         [160, 162, 162, 255],
#         ...,
#         [236, 236, 236, 255],
# ...
