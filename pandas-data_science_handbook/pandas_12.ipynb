# %% [markdown]
# # Vectorized operation in Pandas

# %%
import numpy as np
import pandas as pd

# %%
#vectorization 
x = np.array([2,3,3,4,5,5,6,6])
x*2
# Out:
# array([ 4,  6,  6,  8, 10, 10, 12, 12])

# %%
#problem with  vectorizatoin it is very verbose means details about thing 
data = ['paul','maRy','Pink','Blue']
[s.capitalize() for s in data]
# Out:
# ['Paul', 'Mary', 'Pink', 'Blue']

# %%
#by pandas it is very conveniencet and error prone free 
data = pd.Series(['paul','chinki','kai','tyson'])
data.str.capitalize()
# Out:
# 0      Paul
# 1    Chinki
# 2       Kai
# 3     Tyson
# dtype: object

# %%
#lets start today work 
#table of the pandas string method 
monte = pd.Series(['Graham Chapman', 'John Cleese', 'Terry Gilliam',
'Eric Idle', 'Terry Jones', 'Michael Palin'])

# %%
monte
# Out:
# 0    Graham Chapman
# 1       John Cleese
# 2     Terry Gilliam
# 3         Eric Idle
# 4       Terry Jones
# 5     Michael Palin
# dtype: object

# %%
#mthods of the pandas for doing the vectorization with the pandas 
monte.str.len()
# Out:
# 0    14
# 1    11
# 2    13
# 3     9
# 4    11
# 5    13
# dtype: int64

# %%
monte.str.lower()
# Out:
# 0    graham chapman
# 1       john cleese
# 2     terry gilliam
# 3         eric idle
# 4       terry jones
# 5     michael palin
# dtype: object

# %%
monte.str.capitalize()
# Out:
# 0    Graham chapman
# 1       John cleese
# 2     Terry gilliam
# 3         Eric idle
# 4       Terry jones
# 5     Michael palin
# dtype: object

# %%
monte.str.upper()#for captilzing every letter in the sentence
# Out:
# 0    GRAHAM CHAPMAN
# 1       JOHN CLEESE
# 2     TERRY GILLIAM
# 3         ERIC IDLE
# 4       TERRY JONES
# 5     MICHAEL PALIN
# dtype: object

# %% [markdown]
# monte.str.isdigit()

# %%
monte.str.isdigit()#for checking series have digit  or not
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
monte.str.split()#for splitting the different words in the seiries
# Out:
# 0    [Graham, Chapman]
# 1       [John, Cleese]
# 2     [Terry, Gilliam]
# 3         [Eric, Idle]
# 4       [Terry, Jones]
# 5     [Michael, Palin]
# dtype: object

# %%
monte.str.startswith('T')#for cheking if the values starts with desired character or not
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
monte.str.startswith('A')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
#methods using the regular expresions

# %%
monte.str.extract('([A-Za-z]+)',expand=False)
# Out:
# 0     Graham
# 1       John
# 2      Terry
# 3       Eric
# 4      Terry
# 5    Michael
# dtype: object

# %%
monte.str.extract('([A-Za-z]+)',expand = False)
# Out:
# 0     Graham
# 1       John
# 2      Terry
# 3       Eric
# 4      Terry
# 5    Michael
# dtype: object

# %%
monte.str.findall(r'^[^AEIOU].*[^aeiou]$')#so here basically we are saying that find the values which are not starting and ending with the vowel so we will just get the words that are starting with the consonants
# Out:
# 0    [Graham Chapman]
# 1                  []
# 2     [Terry Gilliam]
# 3                  []
# 4       [Terry Jones]
# 5     [Michael Palin]
# dtype: object

# %%
#Miscellenous methods in between the pandas and pythonn strings

# %% [raw]
# Other methods then basic pandas vectorization methods and regular expression methods
# get Indexes each element
# slice Slices each element
# slice_replace Replaces slice in each element with the passed value
# cat Concatenates strings
# repeat Repeats values
# normalize Returns Unicode form of strings
# pad Adds whitespace to left, right, or both sides of strings
# wrap Splits long strings into lines with length less than a given width
# join Joins strings in each element of the Series with the passed separator
# get_dummies Extracts dummy variables as a DataFrame

# %%
#normal indexing 
monte[0:3]
# Out:
# 0    Graham Chapman
# 1       John Cleese
# 2     Terry Gilliam
# dtype: object

# %%
#slicing of the str 
monte.str[0:3]
# Out:
# 0    Gra
# 1    Joh
# 2    Ter
# 3    Eri
# 4    Ter
# 5    Mic
# dtype: object

# %%
#splliting through the indexes using the slicing of the string 
monte.str.split().str[-1]
# Out:
# 0    Chapman
# 1     Cleese
# 2    Gilliam
# 3       Idle
# 4      Jones
# 5      Palin
# dtype: object

# %%
#indicator codes - codes such we specify something inn the data to make the data look clean and stable
#for example all the people with failing marks as F and students in these certain range or duplicats as a, b c etc

# %%
# #vectorizing the indicator codes 
# as A = “born in America,” B = “born in the United Kingdom,” C = “likes cheese,”
# D = “likes spam”:
full_monte = pd.DataFrame({'name':monte,
                          'info':['B|C|D','B|D','C|A','A|D','A|C|D','B|C']})

# %%
full_monte
# Out:
#              name   info
# 0  Graham Chapman  B|C|D
# 1     John Cleese    B|D
# 2   Terry Gilliam    C|A
# 3       Eric Idle    A|D
# 4     Terry Jones  A|C|D
# 5   Michael Palin    B|C

# %%
#getting dummies of the data 
full_monte['info'].str.get_dummies('|')
# Out:
#    A  B  C  D
# 0  0  1  1  1
# 1  0  1  0  1
# 2  1  0  1  0
# 3  1  0  0  1
# 4  1  0  1  1
# 5  0  1  1  0

# %%
#mini vector  project

# %% [raw]
# Example - Recipe database

# %%
import pandas as pd 
import numpy as np

# %%
recipes = pd.read_json('recipeitems.json',lines=True)

# %%
recipes
# Out:
#                                          _id  \
# 0       {'$oid': '5160756b96cc62079cc2db15'}
# 1       {'$oid': '5160756d96cc62079cc2db16'}
# 2       {'$oid': '5160756f96cc6207a37ff777'}
# 3       {'$oid': '5160757096cc62079cc2db17'}
# 4       {'$oid': '5160757496cc6207a37ff778'}
# ...                                      ...
# 173273  {'$oid': '551c030e96cc6233c0d0dc3d'}
# 173274  {'$oid': '551c030f96cc6233c0d0dc3e'}
# 173275  {'$oid': '551c86b796cc626b1ab4d901'}
# 173276  {'$oid': '551f29b696cc62227991d465'}
# 173277  {'$oid': '551f29c696cc6222a4e0c0e4'}
#
#                                           name  \
# 0              Drop Biscuits and Sausage Gravy
# 1                    Hot Roast Beef Sandwiches
# 2           Morrocan Carrot and Chickpea Salad
# 3                        Mixed Berry Shortcake
# 4                      Pomegranate Yogurt Bowl
# ...                                        ...
# 173273  The Easiest Homemade Vanilla Ice Cream
# ...

# %%
recipes.iloc[0]
# Out:
# _id                                {'$oid': '5160756b96cc62079cc2db15'}
# name                                    Drop Biscuits and Sausage Gravy
# ingredients           Biscuits\n3 cups All-purpose Flour\n2 Tablespo...
# url                   http://thepioneerwoman.com/cooking/2013/03/dro...
# image                 http://static.thepioneerwoman.com/cooking/file...
# ts                                             {'$date': 1365276011104}
# cookTime                                                          PT30M
# source                                                  thepioneerwoman
# recipeYield                                                          12
# datePublished                                                2013-03-11
# prepTime                                                          PT10M
# description           Late Saturday afternoon, after Marlboro Man ha...
# totalTime                                                           NaN
# ...

# %%
#so my work is to make a list of the ingrdient of making a recipe 
recipes.ingredients.str.len().describe()#so here we are taking description of the recipes ingrdients lenght of the full data
# Out:
# count    173278.000000
# mean        244.617926
# std         146.705285
# min           0.000000
# 25%         147.000000
# 50%         221.000000
# 75%         314.000000
# max        9067.000000
# Name: ingredients, dtype: float64

# %%
#so max chracters are 625 and average chracters is 226 and no of ingrdients of the recipes in the data is 1090

# %%
#let find which recipe have 625 character of ingridient 
recipes.name[np.argmax(recipes.ingredients.str.len().describe())]
# Out:
# 'Drop Biscuits and Sausage Gravy'

# %%
#so the recipe with the highest number of ingredients is apple cranberry  crostada

# %%
#letss find the withe lowest character 
recipes.name[np.argmin(recipes.ingredients.str.len().describe())]
# Out:
# 'Mixed Berry Shortcake'

# %%
#apple crisp is with lowest

# %%
#finding how many of them is including inn the the ingridients
recipes.ingredients.str.contains('[Cc]innamon').sum()
# Out:
# np.int64(10526)

# %%
#finding how many of them has misppeled as cinamon 
recipes.ingredients.str.contains('[Cc]inamon').sum()#so there isnt any
# Out:
# np.int64(11)

# %%
recipes.ingredients.str.contains('[Ss]alt').sum()
# Out:
# np.int64(63487)

# %%
#lets check how many  recipes take one hour to cook 
recipes.cookTime.str.contains('1').sum()#so there are 137 dishes which are taking exactly 1 hr to make
# Out:
# 39824

# %% [markdown]
# ## A recipe recommender

# %%
#basically given the ingridient the person have it will recommend a recipe according to data 
spice_list = ['salt', 'pepper', 'oregano', 'sage', 'parsley',
 'rosemary', 'tarragon', 'thyme', 'paprika', 'cumin']

# %%
# %xmode Verbose
import re
#findinng the boolean indexing if the dataframe has these certain spices in the list or not 
spice_df = pd.DataFrame({
    spice : recipes.ingredients.str.contains(spice,re.IGNORECASE
                                             ) for spice in spice_list})
# Out:
# Exception reporting mode: Verbose

# %%
spice_df
# Out:
#          salt  pepper  oregano   sage  parsley  rosemary  tarragon  thyme  \
# 0       False   False    False   True    False     False     False  False
# 1       False   False    False  False    False     False     False  False
# 2        True    True    False  False    False     False     False  False
# 3       False   False    False  False    False     False     False  False
# 4       False   False    False  False    False     False     False  False
# ...       ...     ...      ...    ...      ...       ...       ...    ...
# 173273  False   False    False  False    False     False     False  False
# 173274  False   False    False  False    False     False     False  False
# 173275   True    True    False  False    False     False     False  False
# 173276   True    True    False  False    False     False     False  False
# 173277   True   False    False  False    False     False     False  False
#
#         paprika  cumin
# 0         False  False
# 1         False  False
# ...

# %%
#selecting ingredients with parslye parpika and sage

# %%
selection = spice_df.query('parsley&paprika&tarragon')

# %%
len(selection)
# Out:
# 10

# %%
#so there are 10 dishes with with these three ingrdients

# %%
recipes.name[selection.index]
# Out:
# 2069      All cremat with a Little Gem, dandelion and wa...
# 74964                         Lobster with Thermidor butter
# 93768      Burton's Southern Fried Chicken with White Gravy
# 113926                     Mijo's Slow Cooker Shredded Beef
# 137686                     Asparagus Soup with Poached Eggs
# 140530                                 Fried Oyster Po’boys
# 158475                Lamb shank tagine with herb tabbouleh
# 158486                 Southern fried chicken in buttermilk
# 163175            Fried Chicken Sliders with Pickles + Slaw
# 165243                        Bar Tartine Cauliflower Salad
# Name: name, dtype: object

# %%
#so there are 10 dishes according to ingridents that we have we can multiple possibly with varies combinatinn thatis never ending
