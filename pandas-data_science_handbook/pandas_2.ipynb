# %%
import pandas as pd 
import numpy as np

# %%
#the pandas index object

# %%
ind = pd.Index([1,2,3,4,5])
ind
# Out:
# Index([1, 2, 3, 4, 5], dtype='int64')

# %%
ind[1] = 1#here we get to know pandas index is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ind[1] = 1#here we get to know pandas index is immutable
#
# File ~\Searches\New folder\Lib\site-packages\pandas\core\indexes\base.py:5383, in Index.__setitem__(self, key, value)
#    5381 @final
#    5382 def __setitem__(self, key, value) -> None:
# -> 5383     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
ind.shape,ind.size,ind.ndim
# Out:
# ((5,), 5, 1)

# %%
# they perform same as the numpy array but the difference is they are immutable and numpy array are mutable

# %% [raw]
# index as ordered set
# There are many sets function which can be performed in the pandas as they perform in python

# %%
ind
# Out:
# Index([1, 2, 3, 4, 5], dtype='int64')

# %%
ind_2 = pd.Index([1,2,4,5,6])
ind_2
# Out:
# Index([1, 2, 4, 5, 6], dtype='int64')

# %%
ind_2 & ind#intersectoin function of the sets
# Out:
# Index([1, 2, 0, 4, 4], dtype='int64')

# %%
ind_2 | ind #union function of the sets
# Out:
# Index([1, 2, 7, 5, 7], dtype='int64')

# %%
ind ^ ind_2
# Out:
# Index([0, 0, 7, 1, 3], dtype='int64')

# %%
ind.intersection(ind_2)
# Out:
# Index([1, 2, 4, 5], dtype='int64')

# %%
ind.union(ind_2)
# Out:
# Index([1, 2, 3, 4, 5, 6], dtype='int64')

# %%
ind.symmetric_difference(ind_2)
# Out:
# Index([3, 6], dtype='int64')

# %%
ind.difference(ind_2)
# Out:
# Index([3], dtype='int64')

# %% [markdown]
# # Indexing in the pandas

# %%
import pandas as pd 
data = pd.Series([0.25,0.30,0.10,0.90],
                index = ['a','b','c','d'])

# %%
data
# Out:
# a    0.25
# b    0.30
# c    0.10
# d    0.90
# dtype: float64

# %%
data['a']
# Out:
# np.float64(0.25)

# %%
data['a':'d']
# Out:
# a    0.25
# b    0.30
# c    0.10
# d    0.90
# dtype: float64

# %%
data.keys
# Out:
# <bound method Series.keys of a    0.25
# b    0.30
# c    0.10
# d    0.90
# dtype: float64>

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
'a' in data
# Out:
# True

# %%
'b' in data
# Out:
# True

# %%
'c' in data
# Out:
# True

# %%
'f' in data
# Out:
# False

# %%
0.25 in data
# Out:
# False

# %%
'0.25' in data
# Out:
# False

# %%
#so here did tried boolean indexing in pandas series

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
data.items()

# %%
[data.items()]

# %%
list(data.items())
# Out:
# [('a', 0.25), ('b', 0.3), ('c', 0.1), ('d', 0.9)]

# %%
list(data.items())
# Out:
# [('a', 0.25), ('b', 0.3), ('c', 0.1), ('d', 0.9)]

# %%
data['monu'] = 'is a good boy'

# %%
data
# Out:
# a                0.25
# b                 0.3
# c                 0.1
# d                 0.9
# monu    is a good boy
# dtype: object

# %%
#slicing can be done using the masking and normal slicinng

# %%
data[1:3]
# Out:
# b    0.3
# c    0.1
# dtype: object

# %%
data[::1]
# Out:
# a                0.25
# b                 0.3
# c                 0.1
# d                 0.9
# monu    is a good boy
# dtype: object

# %%
data[1::2]
# Out:
# b    0.3
# d    0.9
# dtype: object

# %%
data[1::1]
# Out:
# b                 0.3
# c                 0.1
# d                 0.9
# monu    is a good boy
# dtype: object

# %%
data[0::2]
# Out:
# a                0.25
# c                 0.1
# monu    is a good boy
# dtype: object

# %%
data[-1::1]
# Out:
# monu    is a good boy
# dtype: object

# %%
# %xmode Verbose
# data[0:2][(data > 0.50)% (data<1.00)]

# %%
import pandas as pd 
import numpy as np
data_2  = pd.Series(['a','b','c'],
                   [1,3,5])

# %%
data_2
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object

# %%
data_2.loc[1]
# Out:
# 'a'

# %%
data_2[3]
# Out:
# 'b'

# %%
data_2.loc[3]
# Out:
# 'b'

# %%
data_2.loc[1]
# Out:
# 'a'

# %%
data_2.loc[3]
# Out:
# 'b'

# %%
data_2.loc[3]
# Out:
# 'b'

# %%
data_2.loc[1:3]
# Out:
# 1    a
# 3    b
# dtype: object

# %%
data_2.loc[1]
# Out:
# 'a'

# %%
data_2.loc[3]
# Out:
# 'b'

# %%
#difference between the normal indexing and loc indexing is that in normal indexing it do not care about objecct , integer etc we can do either way usiongn objects or integers
#but in the loc indexing it will do indexig using the actual indexes not random , natural numbers or etcc

# %%
data_3  = pd.Series(['a','b','c'],
                   ['a','b','d'])

# %%
data_3
# Out:
# a    a
# b    b
# d    c
# dtype: object

# %%
data_3.loc[2]#it is givinng error because 2 is not actual index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Searches\New folder\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self=Index(['a', 'b', 'd'], dtype='object'), key=2)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#         casted_key = 2
#         self = Index(['a', 'b', 'd'], dtype='object')   3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data_3[2]#it is giving even 2 is not integer which makes confusion
# Out:
# C:\Users\Monu Verma\AppData\Local\Temp\ipykernel_26408\325546759.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_3[2]#it is giving even 2 is not integer which makes confusion
# 'c'

# %%
data_3.loc['a':'d']#now it is giving the actual values and we can see that it has actual these indexes in the range
# Out:
# a    a
# b    b
# d    c
# dtype: object

# %%
area = pd.Series({'California': 423967, 'Texas': 695662,
'New York': 141297, 'Florida': 170312,
'Illinois': 149995})
pop = pd.Series({'California': 38332521, 'Texas': 26448193,
'New York': 19651127, 'Florida': 19552860,
'Illinois': 12882135})
data = pd.DataFrame({'area':area, 'pop':pop})
data
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135
