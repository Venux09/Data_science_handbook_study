# %% [markdown]
# # Vectorized operation in Pandas

# %%
import numpy as np
import pandas as pd

# %%
#vectorization 
x = np.array([2,3,3,4,5,5,6,6])
x*2
# Out:
# array([ 4,  6,  6,  8, 10, 10, 12, 12])

# %%
#problem with  vectorizatoin it is very verbose means details about thing 
data = ['paul','maRy','Pink','Blue']
[s.capitalize() for s in data]
# Out:
# ['Paul', 'Mary', 'Pink', 'Blue']

# %%
#by pandas it is very conveniencet and error prone free 
data = pd.Series(['paul','chinki','kai','tyson'])
data.str.capitalize()
# Out:
# 0      Paul
# 1    Chinki
# 2       Kai
# 3     Tyson
# dtype: object

# %%
#lets start today work 
#table of the pandas string method 
monte = pd.Series(['Graham Chapman', 'John Cleese', 'Terry Gilliam',
'Eric Idle', 'Terry Jones', 'Michael Palin'])

# %%
monte
# Out:
# 0    Graham Chapman
# 1       John Cleese
# 2     Terry Gilliam
# 3         Eric Idle
# 4       Terry Jones
# 5     Michael Palin
# dtype: object

# %%
#mthods of the pandas for doing the vectorization with the pandas 
monte.str.len()
# Out:
# 0    14
# 1    11
# 2    13
# 3     9
# 4    11
# 5    13
# dtype: int64

# %%
monte.str.lower()
# Out:
# 0    graham chapman
# 1       john cleese
# 2     terry gilliam
# 3         eric idle
# 4       terry jones
# 5     michael palin
# dtype: object

# %%
monte.str.capitalize()
# Out:
# 0    Graham chapman
# 1       John cleese
# 2     Terry gilliam
# 3         Eric idle
# 4       Terry jones
# 5     Michael palin
# dtype: object

# %%
monte.str.upper()#for captilzing every letter in the sentence
# Out:
# 0    GRAHAM CHAPMAN
# 1       JOHN CLEESE
# 2     TERRY GILLIAM
# 3         ERIC IDLE
# 4       TERRY JONES
# 5     MICHAEL PALIN
# dtype: object

# %% [markdown]
# monte.str.isdigit()

# %%
monte.str.isdigit()#for checking series have digit  or not
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
monte.str.split()#for splitting the different words in the seiries
# Out:
# 0    [Graham, Chapman]
# 1       [John, Cleese]
# 2     [Terry, Gilliam]
# 3         [Eric, Idle]
# 4       [Terry, Jones]
# 5     [Michael, Palin]
# dtype: object

# %%
monte.str.startswith('T')#for cheking if the values starts with desired character or not
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
monte.str.startswith('A')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
#methods using the regular expresions

# %%
monte.str.extract('([A-Za-z]+)',expand=False)
# Out:
# 0     Graham
# 1       John
# 2      Terry
# 3       Eric
# 4      Terry
# 5    Michael
# dtype: object

# %%
monte.str.extract('([A-Za-z]+)',expand = False)
# Out:
# 0     Graham
# 1       John
# 2      Terry
# 3       Eric
# 4      Terry
# 5    Michael
# dtype: object

# %%
monte.str.findall(r'^[^AEIOU].*[^aeiou]$')#so here basically we are saying that find the values which are not starting and ending with the vowel so we will just get the words that are starting with the consonants
# Out:
# 0    [Graham Chapman]
# 1                  []
# 2     [Terry Gilliam]
# 3                  []
# 4       [Terry Jones]
# 5     [Michael Palin]
# dtype: object

# %%
#Miscellenous methods in between the pandas and pythonn strings
