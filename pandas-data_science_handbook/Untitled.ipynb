# %% [markdown]
# # Unique function in the pandas

# %%
import numpy as np 
import pandas as pd 


rng = np.random.RandomState(42)
data = pd.Series(rng.randint(0,10,4))
data
# Out:
# 0    6
# 1    3
# 2    7
# 3    4
# dtype: int32

# %%
#creating a pandas data frame with the help of the numpy randint 

data_2 = pd.DataFrame(rng.randint(0,10,(3,4)),columns= ['a','b','c','d'])

# %%
data_2
# Out:
#    a  b  c  d
# 0  6  9  2  6
# 1  7  4  3  7
# 2  7  2  5  4

# %%
#so we can see actually we created the pandas with numpy series and we can see how they work together actually  they are like bread and butter

# %%
np.exp(data)#finding the expoential for the the value in the series
# Out:
# 0     403.428793
# 1      20.085537
# 2    1096.633158
# 3      54.598150
# dtype: float64
