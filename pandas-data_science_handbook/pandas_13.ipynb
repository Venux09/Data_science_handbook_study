# %% [markdown]
# # Working with the Time Series

# %%
#date and times in the python

# %%
from datetime import datetime 
from dateutil import parser

# %%
datetime(year = 2026,month = 7 , day = 2)
# Out:
# datetime.datetime(2026, 7, 2, 0, 0)

# %%
datetime(year = 2019,month = 1 , day = 1 , hour = 7 ,minute = 30
        )
# Out:
# datetime.datetime(2019, 1, 1, 7, 30)

# %%
#using the python dateutil it just parse the string into timestamp 
date = parser.parse("7:30 4th july 2026")

# %%
date
# Out:
# datetime.datetime(2026, 7, 4, 7, 30)

# %%
date.strftime('%A')
# Out:
# 'Saturday'

# %%
date.strftime('%B')
# Out:
# 'July'

# %%
#type of array of times

# %%
import numpy as np 
date = np.array('2026-07-12',dtype = np.datetime64)#data type of the dates

# %%
date
# Out:
# array('2026-07-12', dtype='datetime64[D]')

# %%
date + np.arange(366)#settinng the range of the number dayys 
#it works according to the real format of date and times on the earth
# Out:
# array(['2026-07-12', '2026-07-13', '2026-07-14', '2026-07-15',
#        '2026-07-16', '2026-07-17', '2026-07-18', '2026-07-19',
#        '2026-07-20', '2026-07-21', '2026-07-22', '2026-07-23',
#        '2026-07-24', '2026-07-25', '2026-07-26', '2026-07-27',
#        '2026-07-28', '2026-07-29', '2026-07-30', '2026-07-31',
#        '2026-08-01', '2026-08-02', '2026-08-03', '2026-08-04',
#        '2026-08-05', '2026-08-06', '2026-08-07', '2026-08-08',
#        '2026-08-09', '2026-08-10', '2026-08-11', '2026-08-12',
#        '2026-08-13', '2026-08-14', '2026-08-15', '2026-08-16',
#        '2026-08-17', '2026-08-18', '2026-08-19', '2026-08-20',
#        '2026-08-21', '2026-08-22', '2026-08-23', '2026-08-24',
#        '2026-08-25', '2026-08-26', '2026-08-27', '2026-08-28',
#        '2026-08-29', '2026-08-30', '2026-08-31', '2026-09-01',
#        '2026-09-02', '2026-09-03', '2026-09-04', '2026-09-05',
#        '2026-09-06', '2026-09-07', '2026-09-08', '2026-09-09',
# ...

# %%
np.datetime64('2026-09-18')#date based
# Out:
# np.datetime64('2026-09-18')

# %%
np.datetime64('2026-09-18 08:45')#minutes based
# Out:
# np.datetime64('2026-09-18T08:45')

# %%
np.datetime64('2026-09-18 08:45:10','ns')#seconds based datetime data
# Out:
# np.datetime64('2026-09-18T08:45:10.000000000')

# %%
#date and timme in the pandas 
import pandas as pd 
date = pd.to_datetime('2026-07-18')

# %%
date
# Out:
# Timestamp('2026-07-18 00:00:00')

# %%
date.strftime('%A')
# Out:
# 'Saturday'

# %%
#pandas time series : indexing by time

# %%
date+pd.to_timedelta(np.arange(12),'D')#vectorizing  like we did in the numpydate time using arange
# Out:
# DatetimeIndex(['2026-07-18', '2026-07-19', '2026-07-20', '2026-07-21',
#                '2026-07-22', '2026-07-23', '2026-07-24', '2026-07-25',
#                '2026-07-26', '2026-07-27', '2026-07-28', '2026-07-29'],
#               dtype='datetime64[ns]', freq=None)

# %%
index = pd.DatetimeIndex(['2020-07-04', '2020-08-04',
 '2021-07-04', '2021-08-04'])

# %%
data = pd.Series([0,1,2,3],index = index)

# %%
data#series with data time series as its Index
# Out:
# 2020-07-04    0
# 2020-08-04    1
# 2021-07-04    2
# 2021-08-04    3
# dtype: int64

# %%
#it is very useful as if we setted a limit of timme and make it index we can retrive real world data by dates in specific time range

# %%
#doing simple slicing 
data['2020-07-04':'2021-08-04']
# Out:
# 2020-07-04    0
# 2020-08-04    1
# 2021-07-04    2
# 2021-08-04    3
# dtype: int64

# %%
#date time speacial indexing 
data['2021']
# Out:
# 2021-07-04    2
# 2021-08-04    3
# dtype: int64

# %%
#most fundamental of the date and time in timestamp which python doesnot provide and also dateIndex where date and time is used as index

# %%
#sinle of the date time will result in creatinng the timestampl using multiple will give parsed datetimeindex 

dates = pd.to_datetime([datetime(2021, 7, 3), '4th of July, 2021','2021-Jul-6', '07-07-2021', '20210708'])

# %%
dates
# Out:
# DatetimeIndex(['2021-07-03', '2021-07-04', '2021-07-06', '2021-07-07',
#                '2021-07-08'],
#               dtype='datetime64[ns]', freq=None)

# %%
dates.to_period('D')
# Out:
# PeriodIndex(['2021-07-03', '2021-07-04', '2021-07-06', '2021-07-07',
#              '2021-07-08'],
#             dtype='period[D]')

# %%
#basically here is the thing that it has becomed type of period of time means it includes the dates and also the days

# %%
#but in the datetimeinedex it is like a snapshot of that event or particular event 
dates-dates[0]
# Out:
# TimedeltaIndex(['0 days', '1 days', '3 days', '4 days', '5 days'], dtype='timedelta64[ns]', freq=None)

# %%
dates-dates[1]#here we reduced the time means years are cutted month also as they were common and in the last when it come to days it produced the output
# Out:
# TimedeltaIndex(['-1 days', '0 days', '2 days', '3 days', '4 days'], dtype='timedelta64[ns]', freq=None)

# %%
dates
# Out:
# DatetimeIndex(['2021-07-03', '2021-07-04', '2021-07-06', '2021-07-07',
#                '2021-07-08'],
#               dtype='datetime64[ns]', freq=None)

# %%
dates[0]
# Out:
# Timestamp('2021-07-03 00:00:00')

# %%
## regular Sequence pd._date_rang and other functionn realted to the datetime convinience

# %%
#np.date_range - it is like settling numpy or pandas delta type thing range of date etc 
pd.date_range('2026-09-21','2027-02-15')#it is fun because it is range of dates i  have left for boards exam i have few before this too
# Out:
# DatetimeIndex(['2026-09-21', '2026-09-22', '2026-09-23', '2026-09-24',
#                '2026-09-25', '2026-09-26', '2026-09-27', '2026-09-28',
#                '2026-09-29', '2026-09-30',
#                ...
#                '2027-02-06', '2027-02-07', '2027-02-08', '2027-02-09',
#                '2027-02-10', '2027-02-11', '2027-02-12', '2027-02-13',
#                '2027-02-14', '2027-02-15'],
#               dtype='datetime64[ns]', length=148, freq='D')

# %%
#date range with period sepcified without specifying the end point 
pd.date_range('2026-09-21',periods=365)
# Out:
# DatetimeIndex(['2026-09-21', '2026-09-22', '2026-09-23', '2026-09-24',
#                '2026-09-25', '2026-09-26', '2026-09-27', '2026-09-28',
#                '2026-09-29', '2026-09-30',
#                ...
#                '2027-09-11', '2027-09-12', '2027-09-13', '2027-09-14',
#                '2027-09-15', '2027-09-16', '2027-09-17', '2027-09-18',
#                '2027-09-19', '2027-09-20'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
#here we can see inn the result we can alter the frequency too of the data 
pd.date_range('2026-09-21-07:47:00',periods=8,freq='h')
# Out:
# DatetimeIndex(['2026-09-21 07:47:00', '2026-09-21 08:47:00',
#                '2026-09-21 09:47:00', '2026-09-21 10:47:00',
#                '2026-09-21 11:47:00', '2026-09-21 12:47:00',
#                '2026-09-21 13:47:00', '2026-09-21 14:47:00'],
#               dtype='datetime64[ns]', freq='h')

# %%
a = pd.period_range('2026-09',periods = 8 , freq='M')

# %%
a-a[0]
# Out:
# Index([<0 * MonthEnds>,      <MonthEnd>, <2 * MonthEnds>, <3 * MonthEnds>,
#        <4 * MonthEnds>, <5 * MonthEnds>, <6 * MonthEnds>, <7 * MonthEnds>],
#       dtype='object')

# %%
pd.timedelta_range(0,periods = 8 , freq='h')
# Out:
# TimedeltaIndex(['0 days 00:00:00', '0 days 01:00:00', '0 days 02:00:00',
#                 '0 days 03:00:00', '0 days 04:00:00', '0 days 05:00:00',
#                 '0 days 06:00:00', '0 days 07:00:00'],
#                dtype='timedelta64[ns]', freq='h')

# %% [raw]
# Listing of Pandas frequency codes
# Code Description Code Description
# D Calendar day B Business day
# W Weekly
# M Month end BM Business month end
# Q Quarter end BQ Business quarter end
# A Year end BA Business year end
# H Hours BH Business hours
# T Minutes
# S Seconds
# L Milliseconds
# U Microseconds
# N Nanoseconds

# %% [raw]
# Listing of start-indexed frequency codes
# Code Description Code Description
# MS Month start BMS Business month start
# QS Quarter start BQS Business quarter start
# AS Year start BAS Business year start
