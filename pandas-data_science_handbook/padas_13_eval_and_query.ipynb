# %% [markdown]
# # Hight Performance Pandas and eval and query

# %%
import numpy as np 
rng = np.random.RandomState(42)
x = rng.random(1000000)
y = rng.random(1000000)
# %timeit x+y
# Out:
# 7.27 ms ± 116 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
#so doing this with the python is waste as it takes a lot time than this one

# %%
#usinng simple maskging in this is also waste because it do breakdown and run the things seprately then it come to the operation it can 
#cause the memory overalload for that high perfoormative tool are used called evall and query

# %%
#lets do the computation using the eval 
import pandas as pd 
nrows , ncoloumns = 1000000,100
df1,df2,df3,df4 = (pd.DataFrame(rng.random((nrows,ncoloumns))) for i in range (4))
#doing simple numpy style computation 
# %timeit df1+df2+df3+df4
# Out:
# 1.36 s ± 60.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
#doing the same computation using the eval of the pandas 

# %timeit pd.eval('df1+df2+df3+df4')
# Out:
# 711 ms ± 33.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
#pd.eval performed the funcction 2x faster that is the big thing when you work with the billions of the rows

# %%
#operation fromm the eval

# %%
#integers 
df1, df2, df3, df4, df5 = (pd.DataFrame(rng.randint(0,1000,(100,3))) for i in range (5))

# %%
#doing the arithmatic operators 
result_1 = -df1*df2/(df1*df2)
result_2 = df1+df2+df3+df4/(df1+df2+df3+df4)

# %%
np.allclose(result_1,result_2)#since they are not equal on the terms
# Out:
# False

# %%
#comparison operators 
result_1 = (df1<df2)&(df2<=df3)&(df3!=df4)
result_2 = pd.eval('df1<df2<=df3!=df4')

# %%
np.allclose(result_1,result_2)
# Out:
# True

# %%
#bitwise operators & and |
result_1 = (df1 < 0.5) & (df2 < 0.5) | (df3 < df4)

result_2 = ('(df1 < 0.5) & (df2 < 0.5) | (df3 < df4)')

# %%
np.allclose(result_1 , result_2 )
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 np.allclose(result_1 , result_2 )
#
# File ~\Searches\New folder\Lib\site-packages\numpy\_core\numeric.py:2365, in allclose(a, b, rtol, atol, equal_nan)
#    2279 @array_function_dispatch(_allclose_dispatcher)
#    2280 def allclose(a, b, rtol=1.e-5, atol=1.e-8, equal_nan=False):
#    2281     """
#    2282     Returns True if two arrays are element-wise equal within a tolerance.
#    2283
#    (...)   2363
#    2364     """
# -> 2365     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2366     return builtins.bool(res)
#
# File ~\Searches\New folder\Lib\site-packages\numpy\_core\numeric.py:2477, in isclose(a, b, rtol, atol, equal_nan)
#    2469 # Make sure y is an inexact type to avoid bad behavior on abs(MIN_INT).
# ...
