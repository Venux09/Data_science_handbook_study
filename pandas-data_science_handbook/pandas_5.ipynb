# %% [markdown]
# ## Handling missing data in the pandas python

# %%
#None pythonic missing data and Null pandas missing data

# %%
import pandas as pd 
import numpy as np

# %%
val1 = np.array([1,2,None,3,4])

# %%
val1
# Out:
# array([1, 2, None, 3, 4], dtype=object)

# %%
for dtype in ['object','int']:
    print(f'dtype = {dtype}')
    # %timeit np.arange(1E6,dtype = dtype ).sum()
    print()
# Out:
# dtype = object
# 131 ms ± 7.76 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# dtype = int
# 6.89 ms ± 1.34 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
val1.sum()#such as thse aggregation function doesnotwork on differenet data types
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 val1.sum()#such as thse aggregation function doesnotwork on differenet data types
#
# File ~\Searches\New folder\Lib\site-packages\numpy\_core\_methods.py:51, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      49 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      50          initial=_NoValue, where=True):
# ---> 51     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
val2 = np.array([1,2,3,4,np.nan])

# %%
val2
# Out:
# array([ 1.,  2.,  3.,  4., nan])

# %%
val2.sum()
# Out:
# np.float64(nan)

# %%
val2.dtype
# Out:
# dtype('float64')

# %%
#Nan is like virus it affects other values also that is other than in the case

# %%
#Nan we can perform function while nan is present

# %%
#for ignoring the nan itself we can perform aggregate

# %%
np.nansum(val2)
# Out:
# np.float64(10.0)

# %%
np.nanmin(val2)
# Out:
# np.float64(1.0)

# %%
np.nanmax(val2)
# Out:
# np.float64(4.0)

# %%
np.nanargmax(val2)
# Out:
# np.int64(3)

# %%
#so we can perform function using numpy in this case

# %%
val1
# Out:
# array([1, 2, None, 3, 4], dtype=object)

# %%
val1[2] = 1

# %%
val1
# Out:
# array([1, 2, 1, 3, 4], dtype=object)

# %%
val1
# Out:
# array([1, 2, 1, 3, 4], dtype=object)

# %%
val1.dtype
# Out:
# dtype('O')

# %%
x = pd.Series(np.arange(2,dtype = int))

# %%
x
# Out:
# 0    0
# 1    1
# dtype: int64

# %%
x[0] = None

# %%
x
# Out:
# 0    NaN
# 1    1.0
# dtype: float64

# %%
#so here we can see that it has been changing the data type to the float so we can expect that nan is a float values that why it is changing the dtype of the pandas series

# %%
#so nan dont change the data type of the floats and objects

# %%
#operatoin on the null values

# %%
data = pd.Series([1, np.nan, 'hello', None])

# %%
data
# Out:
# 0        1
# 1      NaN
# 2    hello
# 3     None
# dtype: object

# %%
data.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
data.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
data[data.notnull()]
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
data[data.isnull()]
# Out:
# 1     NaN
# 3    None
# dtype: object

# %%
#for dropping the na values 
data.dropna()
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
#for filling the na values in the data 
data.fillna(0)
# Out:
# 0        1
# 1        0
# 2    hello
# 3        0
# dtype: object

# %%
df = pd.DataFrame([[1, np.nan, 2],
[2, 3, 5],
[np.nan, 4, 6]])

# %%
df
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
#here we ccnot not drop one value it will either drop the row or full colunmns

# %%
df.dropna()
# Out:
#      0    1  2
# 1  2.0  3.0  5

# %%
#dropping na value in the columns wise 
df.dropna(axis = 1)
# Out:
#    2
# 0  2
# 1  5
# 2  6

# %%
#different ways to filling the values 
df.fillna(method = 'ffill')
# Out:
# C:\Users\Monu Verma\AppData\Local\Temp\ipykernel_22216\1544481526.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'ffill')
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  2.0  4.0  6

# %%
df.fillna('ffill')
# Out:
#        0      1  2
# 0    1.0  ffill  2
# 1    2.0    3.0  5
# 2  ffill    4.0  6

# %%
df.ffill()
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  2.0  4.0  6

# %%
df.fillna(0)
# Out:
#      0    1  2
# 0  1.0  0.0  2
# 1  2.0  3.0  5
# 2  0.0  4.0  6

# %%
df.bfill()
# Out:
#      0    1  2
# 0  1.0  3.0  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
df
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
df.bfill(axis = 1)
# Out:
#      0    1    2
# 0  1.0  2.0  2.0
# 1  2.0  3.0  5.0
# 2  4.0  4.0  6.0

# %%
df.bfill()
# Out:
#      0    1  2
# 0  1.0  3.0  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
df.ffill(axis=1)
# Out:
#      0    1    2
# 0  1.0  1.0  2.0
# 1  2.0  3.0  5.0
# 2  NaN  4.0  6.0

# %%
df.fillna(0.000)
# Out:
#      0    1  2
# 0  1.0  0.0  2
# 1  2.0  3.0  5
# 2  0.0  4.0  6
