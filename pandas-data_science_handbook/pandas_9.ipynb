# %% [markdown]
# ## Merging and join

# %%
#merging and join in the python pandas

# %%
#making a display function one more time

# %%
import pandas as pd 
import numpy as np

# %%
class display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}{1}
    """
    def __init__(self,*args):#storing all the arguments means variable etc 
        self.args = args

    def _repr_html_(self):
        return '\n'.join(self.template.format(a,eval(a)._repr_html_()) for a in self.args)

    def _repr_(self):
        return '\n'.join(a+'\n'+repr(eval(a)) for a in self.args)

# %%
df1 = pd.DataFrame({'employee': ['Bob', 'Jake', 'Lisa', 'Sue'],
'group': ['Accounting', 'Engineering',
'Engineering', 'HR']})
df2 = pd.DataFrame({'employee': ['Lisa', 'Bob', 'Jake', 'Sue'],
'hire_date': [2004, 2008, 2012, 2014]})

# %%
display('df1','df2')
# Out:
# <div style="float: left; padding: 10px;">
#     <p style='font-family:"Courier New", Courier, monospace'>df1<div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>employee</th>
#       <th>group</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bob</td>
#       <td>Accounting</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Jake</td>
#       <td>Engineering</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Lisa</td>
#       <td>Engineering</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Sue</td>
#       <td>HR</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# ...

# %%
df3 = pd.merge(df1,df2)

# %%
df3
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %%
#so this was one to one join

# %%
#many to many join Many-to-many join

# %%
df4 = pd.DataFrame({'group': ['Accounting', 'Engineering', 'HR'],
'supervisor': ['Carly', 'Guido', 'Steve']})

# %%
df4
# Out:
#          group supervisor
# 0   Accounting      Carly
# 1  Engineering      Guido
# 2           HR      Steve

# %%
display('df3','df4')
# Out:
# <div style="float: left; padding: 10px;">
#     <p style='font-family:"Courier New", Courier, monospace'>df3<div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>employee</th>
#       <th>group</th>
#       <th>hire_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bob</td>
#       <td>Accounting</td>
#       <td>2008</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Jake</td>
#       <td>Engineering</td>
#       <td>2012</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Lisa</td>
#       <td>Engineering</td>
#       <td>2004</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Sue</td>
# ...

# %%
pd.merge(df3,df4)
# Out:
#   employee        group  hire_date supervisor
# 0      Bob   Accounting       2008      Carly
# 1     Jake  Engineering       2012      Guido
# 2     Lisa  Engineering       2004      Guido
# 3      Sue           HR       2014      Steve

# %%
#here we can see that there is duplicates of the guido since there are more than one engenerring group guido was superviser as a whole so he will supervse both of them 
#that many on one merging works

# %%
df5 = pd.DataFrame({'group': ['Accounting', 'Accounting',
'Engineering', 'Engineering', 'HR', 'HR'],
                'skills': ['math', 'spreadsheets', 'software', 'math',
'spreadsheets', 'organization']})

# %%
display('df1','df5')
# Out:
# <div style="float: left; padding: 10px;">
#     <p style='font-family:"Courier New", Courier, monospace'>df1<div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>employee</th>
#       <th>group</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bob</td>
#       <td>Accounting</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Jake</td>
#       <td>Engineering</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Lisa</td>
#       <td>Engineering</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Sue</td>
#       <td>HR</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# ...

# %%
pd.merge(df1,df5)
# Out:
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering      software
# 3     Jake  Engineering          math
# 4     Lisa  Engineering      software
# 5     Lisa  Engineering          math
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization

# %%
#so till now we understood how one on one , many on one , and many to many  works in the pandas for merging the data frames which matches

# %%
#the speicification keys in the pandas 
pd.merge(df1,df5, on='group')
# Out:
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering      software
# 3     Jake  Engineering          math
# 4     Lisa  Engineering      software
# 5     Lisa  Engineering          math
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization

# %%
#if i have to explain it is simply we just telling on what basis you have to do this merging simple as that

# %%
#now merging on the different columns if the data frames are not in columns but the stuff feels same

# %%
"using left join and right join in the pandas"
# Out:
# 'using left join and right join in the pandas'

# %%
df3
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %%
df3_ = pd.DataFrame({'name': ['Bob', 'Jake', 'Lisa', 'Sue'],
'salary': [70000, 80000, 120000, 90000]})

# %%
df3_
# Out:
#    name  salary
# 0   Bob   70000
# 1  Jake   80000
# 2  Lisa  120000
# 3   Sue   90000

# %%
display('df1','df3_'
       )
# Out:
# <div style="float: left; padding: 10px;">
#     <p style='font-family:"Courier New", Courier, monospace'>df1<div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>employee</th>
#       <th>group</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bob</td>
#       <td>Accounting</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Jake</td>
#       <td>Engineering</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Lisa</td>
#       <td>Engineering</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Sue</td>
#       <td>HR</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# ...

# %%
display('df1','df3_','pd.merge(df1,df3_,left_on = "employee" ,right_on = "name").drop("name",axis=1)')#so here we are just join on basis of common traits we are finding in the data
# Out:
# <div style="float: left; padding: 10px;">
#     <p style='font-family:"Courier New", Courier, monospace'>df1<div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>employee</th>
#       <th>group</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bob</td>
#       <td>Accounting</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Jake</td>
#       <td>Engineering</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Lisa</td>
#       <td>Engineering</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Sue</td>
#       <td>HR</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# ...

# %%
#left_index and right_index in the python pandas

# %%
#basically here we are not  joing on the basis of the coloumns but on the basis of the index

# %%
#for that we have tset the index first too get accurate result

# %%
df1
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR

# %%
df2
# Out:
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2     Jake       2012
# 3      Sue       2014

# %%
#so here basically we are just replacing and default index to the employee column  that has been given in the data frames 
df1a = df1.set_index('employee')
df2a = df2.set_index('employee')

# %%
display('df1a','df2a')
# Out:
# <div style="float: left; padding: 10px;">
#     <p style='font-family:"Courier New", Courier, monospace'>df1a<div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>group</th>
#     </tr>
#     <tr>
#       <th>employee</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Bob</th>
#       <td>Accounting</td>
#     </tr>
#     <tr>
#       <th>Jake</th>
#       <td>Engineering</td>
#     </tr>
#     <tr>
#       <th>Lisa</th>
#       <td>Engineering</td>
#     </tr>
#     <tr>
#       <th>Sue</th>
#       <td>HR</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# <div style="float: left; padding: 10px;">
# ...

# %%
#index based merging not on the basis of the columns or rows but just on the basis of the index that we get provided not provided we have made it ourself
display('df1a','df2a','pd.merge(df1a,df2a,left_index = True , right_index = True)')
# Out:
# <div style="float: left; padding: 10px;">
#     <p style='font-family:"Courier New", Courier, monospace'>df1a<div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>group</th>
#     </tr>
#     <tr>
#       <th>employee</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Bob</th>
#       <td>Accounting</td>
#     </tr>
#     <tr>
#       <th>Jake</th>
#       <td>Engineering</td>
#     </tr>
#     <tr>
#       <th>Lisa</th>
#       <td>Engineering</td>
#     </tr>
#     <tr>
#       <th>Sue</th>
#       <td>HR</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# <div style="float: left; padding: 10px;">
# ...

# %%
df2a.join(df1a)#index based merging not the coloum based
# Out:
#           hire_date        group
# employee
# Lisa           2004  Engineering
# Bob            2008   Accounting
# Jake           2012  Engineering
# Sue            2014           HR

# %% [markdown]
# ### Specifiying the set arthimatics for the joins

# %%
df6 = pd.DataFrame({'name': ['Peter', 'Paul', 'Mary'],
'food': ['fish', 'beans', 'bread']},
columns=['name', 'food'])
df7 = pd.DataFrame({'name': ['Mary', 'Joseph'],
'drink': ['wine', 'beer']},
columns=['name', 'drink'])

# %%
df6
# Out:
#     name   food
# 0  Peter   fish
# 1   Paul  beans
# 2   Mary  bread

# %%
df7
# Out:
#      name drink
# 0    Mary  wine
# 1  Joseph  beer

# %%
pd.merge(df6,df7)#here only one thing is common that why only mary is comming
# Out:
#    name   food drink
# 0  Mary  bread  wine

# %%
#trying the inner 
pd.merge(df6,df7,how='inner')
# Out:
#    name   food drink
# 0  Mary  bread  wine

# %%
#lets try outer ones so nan can be produced 
pd.merge(df6,df7,how='outer')
# Out:
#      name   food drink
# 0  Joseph    NaN  beer
# 1    Mary  bread  wine
# 2    Paul  beans   NaN
# 3   Peter   fish   NaN

# %%
#on the basis of the left 
pd.merge(df6,df7,how = "left")
# Out:
#     name   food drink
# 0  Peter   fish   NaN
# 1   Paul  beans   NaN
# 2   Mary  bread  wine

# %%
#overlapping  column names

# %%
df8 = pd.DataFrame({'name': ['Bob', 'Jake', 'Lisa', 'Sue'],
'rank': [1, 2, 3, 4]})
df9 = pd.DataFrame({'name': ['Bob', 'Jake', 'Lisa', 'Sue'],
'rank': [3, 1, 4, 2]})

# %%
#so basically here we can see that there is conflicting columns names where there is two different types of ranks 
display('df8','df9','pd.merge(df8,df9,on="name")')
# Out:
# <div style="float: left; padding: 10px;">
#     <p style='font-family:"Courier New", Courier, monospace'>df8<div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bob</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Jake</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Lisa</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Sue</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# <div style="float: left; padding: 10px;">
# ...

# %%
#here we seen a interseting things on the  basis that there was conflicting columns merge functoin itselt setted the values value_x and value_y on the basis of itself

# %%
#setting the suffix ourself 
pd.merge(df8,df9,on='name',suffixes = ['_L','_y'])
# Out:
#    name  rank_L  rank_y
# 0   Bob       1       3
# 1  Jake       2       1
# 2  Lisa       3       4
# 3   Sue       4       2

# %% [markdown]
# ## Performing all these techniques on the us data

# %%
#Us data

# %%
#downloading the  data of the us from the git hub repository

# %%
pop = pd.read_csv('state-population.csv')
area = pd.read_csv('state-areas.csv')
abbrevs = pd.read_csv('state-abbrevs.csv')

# %%
pop
# Out:
#      state/region     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# ...           ...      ...   ...          ...
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0
#
# [2544 rows x 4 columns]

# %%
area
# Out:
#                    state  area (sq. mi)
# 0                Alabama          52423
# 1                 Alaska         656425
# 2                Arizona         114006
# 3               Arkansas          53182
# 4             California         163707
# 5               Colorado         104100
# 6            Connecticut           5544
# 7               Delaware           1954
# 8                Florida          65758
# 9                Georgia          59441
# 10                Hawaii          10932
# 11                 Idaho          83574
# 12              Illinois          57918
# 13               Indiana          36420
# 14                  Iowa          56276
# 15                Kansas          82282
# 16              Kentucky          40411
# 17             Louisiana          51843
# 18                 Maine          35387
# 19              Maryland          12407
# 20         Massachusetts          10555
# 21              Michigan          96810
# ...

# %%
pop
# Out:
#      state/region     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# ...           ...      ...   ...          ...
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0
#
# [2544 rows x 4 columns]

# %%
area
# Out:
#                    state  area (sq. mi)
# 0                Alabama          52423
# 1                 Alaska         656425
# 2                Arizona         114006
# 3               Arkansas          53182
# 4             California         163707
# 5               Colorado         104100
# 6            Connecticut           5544
# 7               Delaware           1954
# 8                Florida          65758
# 9                Georgia          59441
# 10                Hawaii          10932
# 11                 Idaho          83574
# 12              Illinois          57918
# 13               Indiana          36420
# 14                  Iowa          56276
# 15                Kansas          82282
# 16              Kentucky          40411
# 17             Louisiana          51843
# 18                 Maine          35387
# 19              Maryland          12407
# 20         Massachusetts          10555
# 21              Michigan          96810
# ...

# %%
abbrevs
# Out:
#                    state abbreviation
# 0                Alabama           AL
# 1                 Alaska           AK
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA
# 5               Colorado           CO
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# 19                 Maine           ME
# 20               Montana           MT
# 21              Nebraska           NE
# 22                Nevada           NV
# 23         New Hampshire           NH
# ...

# %%
display('pop.head()','area.head()','abbrevs.head()')
# Out:
# <div style="float: left; padding: 10px;">
#     <p style='font-family:"Courier New", Courier, monospace'>pop.head()<div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state/region</th>
#       <th>ages</th>
#       <th>year</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AL</td>
#       <td>under18</td>
#       <td>2012</td>
#       <td>1117489.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AL</td>
#       <td>total</td>
#       <td>2012</td>
#       <td>4817528.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AL</td>
#       <td>under18</td>
#       <td>2010</td>
# ...

# %%
#the info we want to find  in this data is basically usa top states and the states name in 2010

# %%
merge = pd.merge(pop,abbrevs,how='outer',left_on = 'state/region', right_on = 'abbreviation')

# %%
merge
# Out:
#      state/region     ages  year  population    state abbreviation
# 0              AK    total  1990    553290.0   Alaska           AK
# 1              AK  under18  1990    177502.0   Alaska           AK
# 2              AK    total  1992    588736.0   Alaska           AK
# 3              AK  under18  1991    182180.0   Alaska           AK
# 4              AK  under18  1992    184878.0   Alaska           AK
# ...           ...      ...   ...         ...      ...          ...
# 2539           WY  under18  1993    137458.0  Wyoming           WY
# 2540           WY    total  1991    459260.0  Wyoming           WY
# 2541           WY  under18  1991    136720.0  Wyoming           WY
# 2542           WY  under18  1990    136078.0  Wyoming           WY
# 2543           WY    total  1990    453690.0  Wyoming           WY
#
# [2544 rows x 6 columns]

# %%
#dropping the duplicate abbreviation 
merge  = merge.drop('abbreviation',axis = 1)

# %%
merge
# Out:
#      state/region     ages  year  population    state
# 0              AK    total  1990    553290.0   Alaska
# 1              AK  under18  1990    177502.0   Alaska
# 2              AK    total  1992    588736.0   Alaska
# 3              AK  under18  1991    182180.0   Alaska
# 4              AK  under18  1992    184878.0   Alaska
# ...           ...      ...   ...         ...      ...
# 2539           WY  under18  1993    137458.0  Wyoming
# 2540           WY    total  1991    459260.0  Wyoming
# 2541           WY  under18  1991    136720.0  Wyoming
# 2542           WY  under18  1990    136078.0  Wyoming
# 2543           WY    total  1990    453690.0  Wyoming
#
# [2544 rows x 5 columns]

# %%
merge.head()
# Out:
#   state/region     ages  year  population   state
# 0           AK    total  1990    553290.0  Alaska
# 1           AK  under18  1990    177502.0  Alaska
# 2           AK    total  1992    588736.0  Alaska
# 3           AK  under18  1991    182180.0  Alaska
# 4           AK  under18  1992    184878.0  Alaska

# %%
#checking is there is any null values 
merge.isnull().any()#basically any functionn helps in getting if there is any in the columns wise rather  than full data frame table
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state            True
# dtype: bool

# %%
#doing fancy indexing 
merge[merge['population'].isnull()].head()
# Out:
#      state/region     ages  year  population state
# 1872           PR  under18  1990         NaN   NaN
# 1873           PR    total  1990         NaN   NaN
# 1874           PR    total  1991         NaN   NaN
# 1875           PR  under18  1991         NaN   NaN
# 1876           PR    total  1993         NaN   NaN

# %%
merge.loc[merge['state'].isnull(),'state/region'].unique()
# Out:
# array(['PR', 'USA'], dtype=object)

# %%
#so here we can see that PR And Usa are the abbrevtionn which have null keys
merge.loc[merge['state/region'] == 'PR','state'] = 'Puerto Rico' #so here filled all the abbrevatoin keys with pr nan state values with its name

# %%
merge.loc[merge['state/region'] == 'USA','state'] = 'United States of America'#So here we setted like previous one where we were finding usa key states as nun

# %%
merge['state'].isnull().any()
# Out:
# np.False_

# %%
#so lets check any null more valuese 
merge.isnull().any()
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state           False
# dtype: bool

# %%
#so now we will merge all the data so noow we will have area  , state, population combined

# %%
final = pd.merge(merge,area, on = 'state' , how = 'left')

# %%
_
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state           False
# dtype: bool

# %%
final
# Out:
#      state/region     ages  year  population    state  area (sq. mi)
# 0              AK    total  1990    553290.0   Alaska       656425.0
# 1              AK  under18  1990    177502.0   Alaska       656425.0
# 2              AK    total  1992    588736.0   Alaska       656425.0
# 3              AK  under18  1991    182180.0   Alaska       656425.0
# 4              AK  under18  1992    184878.0   Alaska       656425.0
# ...           ...      ...   ...         ...      ...            ...
# 2539           WY  under18  1993    137458.0  Wyoming        97818.0
# 2540           WY    total  1991    459260.0  Wyoming        97818.0
# 2541           WY  under18  1991    136720.0  Wyoming        97818.0
# 2542           WY  under18  1990    136078.0  Wyoming        97818.0
# 2543           WY    total  1990    453690.0  Wyoming        97818.0
#
# [2544 rows x 6 columns]

# %%
#checking any null valules in the final data 
final.isnull().any()
# Out:
# state/region     False
# ages             False
# year             False
# population        True
# state            False
# area (sq. mi)     True
# dtype: bool

# %%
final['state'][final['area (sq. mi)'].isnull()].unique()
# Out:
# array(['United States of America'], dtype=object)

# %%
final.dropna(inplace = True)

# %%
final.head()
# Out:
#   state/region     ages  year  population   state  area (sq. mi)
# 0           AK    total  1990    553290.0  Alaska       656425.0
# 1           AK  under18  1990    177502.0  Alaska       656425.0
# 2           AK    total  1992    588736.0  Alaska       656425.0
# 3           AK  under18  1991    182180.0  Alaska       656425.0
# 4           AK  under18  1992    184878.0  Alaska       656425.0

# %%
final.isnull().any()
# Out:
# state/region     False
# ages             False
# year             False
# population       False
# state            False
# area (sq. mi)    False
# dtype: bool

# %%
#so now data is lceand at the same time we have combined the data also.

# %%
data2010 = final.query("year==2010 & ages == 'total'")

# %%
data2010
# Out:
#      state/region   ages  year  population                 state  \
# 43             AK  total  2010    713868.0                Alaska
# 51             AL  total  2010   4785570.0               Alabama
# 141            AR  total  2010   2922280.0              Arkansas
# 149            AZ  total  2010   6408790.0               Arizona
# 197            CA  total  2010  37333601.0            California
# 283            CO  total  2010   5048196.0              Colorado
# 293            CT  total  2010   3579210.0           Connecticut
# 341            DC  total  2010    605125.0  District of Columbia
# 427            DE  total  2010    899711.0              Delaware
# 475            FL  total  2010  18846054.0               Florida
# 485            GA  total  2010   9713248.0               Georgia
# 570            HI  total  2010   1363731.0                Hawaii
# 618            IA  total  2010   3050314.0                  Iowa
# ...

# %% [raw]
# problem :- so now we have to give answer that population density from top to bottom with state names
# solution is basically we have to calculate the density of the populations and have to sort it

# %%
density = data2010['population']/data2010['area (sq. mi)']

# %%
#so now will sort the values from high to low 
density.sort_values(ascending = False , inplace = True )

# %%
density.head()
# Out:
# state
# District of Columbia    8898.897059
# Puerto Rico             1058.665149
# New Jersey              1009.253268
# Rhode Island             681.339159
# Connecticut              645.600649
# dtype: float64

# %%
density.tail()
# Out:
# state
# South Dakota    10.583512
# North Dakota     9.537565
# Montana          6.736171
# Wyoming          5.768079
# Alaska           1.087509
# dtype: float64

# %%
density.head()
# Out:
# state
# District of Columbia    8898.897059
# Puerto Rico             1058.665149
# New Jersey              1009.253268
# Rhode Island             681.339159
# Connecticut              645.600649
# dtype: float64

# %%
#so the problem is solved
