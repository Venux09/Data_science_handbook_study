# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
data = pd.Series([1,2,3,4,5])

# %%
data#series of the data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data.values#it tell the values of  the function that we have putted in the array
# Out:
# array([1, 2, 3, 4, 5])

# %%
data.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
data[1]
# Out:
# np.int64(2)

# %%
data[:]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data[1:2]#just like indexing in the numpy arrat
# Out:
# 1    2
# dtype: int64

# %%
series = pd.Series([1,2,3,4,5,6],
                  index=['a','b','c','d','e','f'])

# %%
series['a']#so here we did something interesting that we can also define the particular index in the data
# Out:
# np.int64(1)

# %%
series = pd.Series([1,2,3,4,5,6],
                  index=['a','b','c','d','e','f'])

# %%
series
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
population_dict = {'California': 38332521,
'Texas': 26448193,
'New York': 19651127,
'Florida': 19552860,
'Illinois': 12882135}

# %%
#creating the seires 
popuation_series = pd.Series(population_dict)
popuation_series
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
popuation_series['California']
# Out:
# np.int64(38332521)

# %%
popuation_series[0:3]
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# dtype: int64

# %%
popuation_series['California':'Florida']
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# dtype: int64

# %%
#diff ways to create an pandas series 
series_2 = pd.Series(5,index = [1,2,3,4,5,6,7])#in pandas series is scalar values can repeat 
series_2
# Out:
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# 6    5
# 7    5
# dtype: int64

# %%
students = {
    1: {"name": "Aarav", "marks": 85},
    2: {"name": "Diya", "marks": 92},
    3: {"name": "Ishaan", "marks": 74}
}

# %%
pd_3 = pd.Series(students)

# %%
pd_3
# Out:
# 1     {'name': 'Aarav', 'marks': 85}
# 2      {'name': 'Diya', 'marks': 92}
# 3    {'name': 'Ishaan', 'marks': 74}
# dtype: object

# %% [markdown]
# ### Dataframes

# %%
area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297,
'Florida': 170312, 'Illinois': 149995}

# %%
pd_4 = pd.Series(area_dict)
pd_4
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
PD_DATAFRAME  = pd.DataFrame({'Population':popuation_series,
                             'area':area_dict})#here the index is overlapping so there is not error and also it is making a dataframes

# %%
PD_DATAFRAME
# Out:
#             Population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %%
PD_DATAFRAME.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %%
PD_DATAFRAME.columns
# Out:
# Index(['Population', 'area'], dtype='object')

# %%
PD_DATAFRAME.values
# Out:
# array([[38332521,   423967],
#        [26448193,   695662],
#        [19651127,   141297],
#        [19552860,   170312],
#        [12882135,   149995]])

# %%
#so here like series both functoin can be performed as weel as as there are columns as they are added
