# %%
#common and important feature of jupyter notebooks and also python 
help(len)#give the document of the function
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
help(sum)
# Out:
# Help on built-in function sum in module builtins:
#
# sum(iterable, /, start=0)
#     Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
#     When the iterable is empty, return the start value.
#     This function is intended specifically for use with numeric values and may
#     reject non-numeric types.

# %%
sum?
# Out:
# Signature: sum(iterable, /, start=0)
# Docstring:
# Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
# When the iterable is empty, return the start value.
# This function is intended specifically for use with numeric values and may
# reject non-numeric types.
# Type:      builtin_function_or_method

# %%
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
int?
# Out:
# Init signature: int(self, /, *args, **kwargs)
# Docstring:
# int([x]) -> integer
# int(x, base=10) -> integer
#
# Convert a number or string to an integer, or return 0 if no arguments
# are given.  If x is a number, return x.__int__().  For floating-point
# numbers, this truncates towards zero.
#
# If x is not a number or if base is given, then x must be a string,
# bytes, or bytearray instance representing an integer literal in the
# given base.  The literal can be preceded by '+' or '-' and be surrounded
# by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
# Base 0 means to interpret the base from the string as an integer literal.
# >>> int('0b100', base=0)
# 4
# Type:           type
# Subclasses:     bool, IntEnum, IntFlag, _NamedIntConstant, _ZeroSentinel, Handle

# %%
L = [1,2,3]
L.insert?
# Out:
# Signature: L.insert(index, object, /)
# Docstring: Insert object before index.
# Type:      builtin_function_or_method

# %%
L?
# Out:
# Type:        list
# String form: [1, 2, 3]
# Length:      3
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
#trying on the def function 
def square(x):
    'returnt the square of the value x'
    return x**2
square?
# Out:
# Signature: square(x)
# Docstring: returnt the square of the value x
# File:      c:\users\monu verma\appdata\local\temp\ipykernel_18664\1418989397.py
# Type:      function

# %%
#accessing the source code of the funtoin using the ipython scrip 
square??
# Out:
# Signature: square(x)
# Source:
# def square(x):
#     'returnt the square of the value x'
#     return x**2
# File:      c:\users\monu verma\appdata\local\temp\ipykernel_18664\1418989397.py
# Type:      function

# %%
len??
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
square?
# Out:
# Signature: square(x)
# Docstring: returnt the square of the value x
# File:      c:\users\monu verma\appdata\local\temp\ipykernel_18664\1418989397.py
# Type:      function

# %%
square??
# Out:
# Signature: square(x)
# Source:
# def square(x):
#     'returnt the square of the value x'
#     return x**2
# File:      c:\users\monu verma\appdata\local\temp\ipykernel_18664\1418989397.py
# Type:      function

# %%
str??
# Out:
# Init signature: str(self, /, *args, **kwargs)
# Docstring:
# str(object='') -> str
# str(bytes_or_buffer[, encoding[, errors]]) -> str
#
# Create a new string object from the given object. If encoding or
# errors is specified, then the object must expose a data buffer
# that will be decoded using the given encoding and error handler.
# Otherwise, returns the result of object.__str__() (if defined)
# or repr(object).
# encoding defaults to 'utf-8'.
# errors defaults to 'strict'.
# Type:           type
# Subclasses:     StrEnum, DeferredConfigString, _rstr, LSString, include, Keys, InputMode, ColorDepth, CompleteStyle, FoldedCase, ...

# %%
str?
# Out:
# Init signature: str(self, /, *args, **kwargs)
# Docstring:
# str(object='') -> str
# str(bytes_or_buffer[, encoding[, errors]]) -> str
#
# Create a new string object from the given object. If encoding or
# errors is specified, then the object must expose a data buffer
# that will be decoded using the given encoding and error handler.
# Otherwise, returns the result of object.__str__() (if defined)
# or repr(object).
# encoding defaults to 'utf-8'.
# errors defaults to 'strict'.
# Type:           type
# Subclasses:     StrEnum, DeferredConfigString, _rstr, LSString, include, Keys, InputMode, ColorDepth, CompleteStyle, FoldedCase, ...

# %%
max?
# Out:
# Docstring:
# max(iterable, *[, default=obj, key=func]) -> value
# max(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its biggest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more positional arguments, return the largest argument.
# Type:      builtin_function_or_method

# %%
max??
# Out:
# Docstring:
# max(iterable, *[, default=obj, key=func]) -> value
# max(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its biggest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more positional arguments, return the largest argument.
# Type:      builtin_function_or_method

# %%
min,max?
# Out:
# Docstring:
# max(iterable, *[, default=obj, key=func]) -> value
# max(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its biggest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more positional arguments, return the largest argument.
# Type:      builtin_function_or_method

# %%
min?
# Out:
# Docstring:
# min(iterable, *[, default=obj, key=func]) -> value
# min(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its smallest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more positional arguments, return the smallest argument.
# Type:      builtin_function_or_method

# %%
min,max?
# Out:
# Docstring:
# max(iterable, *[, default=obj, key=func]) -> value
# max(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its biggest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more positional arguments, return the largest argument.
# Type:      builtin_function_or_method

# %%
max,min?
# Out:
# Docstring:
# min(iterable, *[, default=obj, key=func]) -> value
# min(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its smallest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more positional arguments, return the smallest argument.
# Type:      builtin_function_or_method

# %%
min?
# Out:
# Docstring:
# min(iterable, *[, default=obj, key=func]) -> value
# min(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its smallest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more positional arguments, return the smallest argument.
# Type:      builtin_function_or_method

# %%
min??
# Out:
# Docstring:
# min(iterable, *[, default=obj, key=func]) -> value
# min(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its smallest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more positional arguments, return the smallest argument.
# Type:      builtin_function_or_method

# %%
#?? and ? sometimes are same because many methods inthe python in wirtten inthe c  language so there source code is C and can't be acnessed here

# %%
list?
# Out:
# Init signature: list(iterable=(), /)
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.
# Type:           type
# Subclasses:     _List, _HashedSeq, StackSummary, _Threads, ConvertingList, DeferredConfigList, _ymd, SList, _ImmutableLineList, FormattedText, ...

# %%
#using tab for seeing built in function of the python and other things with and it can detect function , or defined function in your code and also the libraries 
L.clear
L.copy
L.count
#first alphabet and many then then can be written for narrowaing the down to the tab list
# Out:
# <function list.count(value, /)>

# %%
L.append
L.append
L.reverse
#and many others
# Out:
# <function list.reverse()>

# %%
a = [1,3,4,"monu"]

# %%
a?
# Out:
# Type:        list
# String form: [1, 3, 4, 'monu']
# Length:      4
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
a??
# Out:
# Type:        list
# String form: [1, 3, 4, 'monu']
# Length:      4
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
#_funtion 
L.__add__
#etc and many others
# Out:
# <method-wrapper '__add__' of list object at 0x0000025971C22880>
